# %%
# !pip install jsonformer
# Out:
# Collecting jsonformer
#   Downloading jsonformer-0.12.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: termcolor<3.0.0,>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from jsonformer) (2.5.0)
# Downloading jsonformer-0.12.0-py3-none-any.whl (6.6 kB)
# Installing collected packages: jsonformer
# Successfully installed jsonformer-0.12.0

# %%
from google.colab import drive
import pandas as pd
drive.mount('/content/drive')

# Now provide the full path to your file in Google Drive
csv_file = "/content/drive/My Drive/expermintstarcoder/PuppetScripts_V2.csv"
csv_file_ansible = "/content/drive/My Drive/expermintstarcoder/merged_file_ansible_defect.csv"
df = pd.read_csv(csv_file)
# Out:
# Mounted at /content/drive

# %%
from huggingface_hub import login
login(token="")

# %%
from google.colab import drive
import pandas as pd
import torch
import json
import csv
from jsonformer import Jsonformer
from transformers import AutoModelForCausalLM, AutoTokenizer

# Mount Google Drive
drive.mount('/content/drive')

# Define CSV file path in Google Drive
csv_file = "/content/drive/My Drive/expermintstarcoder/PuppetScripts_V2.csv"  # Input CSV file path
output_file = "/content/drive/My Drive/expermintstarcoder/output_results.csv"  # Output CSV file path

# Load the CSV file from Google Drive
df = pd.read_csv(csv_file)

# Check if GPU is available
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# Load model and tokenizer from Hugging Face model hub
model_name = "bigcode/starcoder2-7b"  # Replace with the correct model name

print("Loading model from Hugging Face model hub...")
model = AutoModelForCausalLM.from_pretrained(model_name, torch_dtype=torch.float16).to(device)
tokenizer = AutoTokenizer.from_pretrained(model_name)
print("Model loaded successfully!")

# Put model in evaluation mode
model.eval()

# Fix tokenizer pad token issue
tokenizer.pad_token = tokenizer.eos_token

# Define JSON Schema (Ensures long responses)
json_schema = {
    "type": "object",
    "properties": {
        "issues_found": {
            "type": "array",
            "items": {
                "type": "object",
                "properties": {
                    "misconfigured_snippet": {"type": "string"},

                }
            }
        }
    }
}

# Function to analyze Puppet misconfiguration
def analyze_misconfiguration(code_snippet):
    # Define structured prompt
    prompt = f"""
    You are a **security expert specializing in Puppet configuration security**. Your task is to analyze the following Puppet code and identify **all possible security risks**.

    **Puppet Script to Analyze**:
    ```puppet
    {code_snippet}
    ```

    ### **Response Format**
    Return the response in **valid JSON format**:
    ```json
    {{
      "issues_found": [
        {{
          "misconfigured_snippet": "<misconfigured_snippet_1>",

        }},
        {{
          "misconfigured_snippet": "<misconfigured_snippet_2>",

        }}
      ]
    }}
    ```

    ### **Instructions**
    - **Only report security risks**. Ignore syntax or general best practices.
    - If there are **multiple risks**, list **all** of them.
    - If the script **has no security misconfiguration**, return an **empty array**.
    - **Return ONLY JSON** (without extra text or explanations).
    """

    max_length = min(len(tokenizer.encode(prompt)), 6000)

    # Tokenize input and move to GPU (Allowing longer input)
    inputs = tokenizer(
        prompt,
        return_tensors="pt",
        max_length=max_length,
        truncation=True,
        padding="max_length"
    ).to(device)

    # Generate structured output using Jsonformer with high token limit
    with torch.no_grad():
        structured_output = Jsonformer(
            model,
            tokenizer,
            json_schema=json_schema,
            prompt=prompt,
            max_string_token_length=max_length,
        )

    return structured_output()

# Open CSV file and write header only once
with open(output_file, mode="w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["Script", "Label", "MisconfigurationFound", "Reason"])  #

# Process each row and save immediately after processing
for index, row in df.iterrows():
    script_content = str(row.get("Script.Content", "")).strip()
    defect_label = str(row.get("Defect.Label", "")).strip()

    if not script_content:
        print(f" Skipping Row {index + 1} (Empty Script)")
        continue

    try:
        # Analyze misconfiguration
        result = analyze_misconfiguration(script_content)
        issues = result.get("issues_found", [])

        # Convert multiple misconfigurations and reasons into a single comma-separated string
        misconfigured_snippets = ", ".join([issue.get("misconfigured_snippet", "Unknown") for issue in issues]) if issues else "No issues detected"
        reasons = ", ".join([issue.get("reason", "No explanation provided") for issue in issues]) if issues else "None"

        # Save results directly into the CSV
        with open(output_file, mode="a", newline="", encoding="utf-8") as f:
            writer = csv.writer(f)
            writer.writerow([script_content, defect_label, misconfigured_snippets, reasons])

        # Print result
        print(f"\n🔹 **Processed Row {index + 1}/{len(df)}** 🔹\n")
        print(json.dumps(issues, indent=4))

    except Exception as e:
        print(f"Error processing Row {index + 1}: {e}")

print("\n**All scripts analyzed successfully! Results saved in 'output_results.csv'**")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Using device: cuda
# Loading model from Hugging Face model hub...
# model.safetensors:  54%|#####4    | 6.60G/12.1G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/7.88k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/777k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/442k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.06M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/958 [00:00<?, ?B/s]
# Model loaded successfully!
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Streaming output truncated to the last 5000 lines.
#     }
# ]
#
# 🔹 **Processed Row 1325/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "user { 'xvfb': ensure => present, gid => 'xvfb', shell => '/bin/false', home => '/nonexistent', system => true, }"
#     }
# ]
# Error processing Row 1326: CUDA out of memory. Tried to allocate 128.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 96.12 MiB is free. Process 7279 has 14.64 GiB memory in use. Of the allocated memory 14.45 GiB is allocated by PyTorch, and 66.33 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
# 🔹 **Processed Row 1327/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "warning('osnailyfacter/modular/./murano/db.pp is deprecated in mitaka and will be removed in newton. please use openstack_tasks/examples/./murano/db.pp')"
#     }
# ]
#
# 🔹 **Processed Row 1328/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1329/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "package { 'nbconvert': ensure => present, provider => pip, }"
#     }
# ]
#
# 🔹 **Processed Row 1330/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1331/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1332/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "nova::manage::network { network => '10.0.0.0/24', label => 'novanetwork', num_networks => 1, network_size => 255, project => 'admin', vlan_start => undef, allowed_start => undef, allowed_end => undef, dns1 => undef, dns2 => undef, }"
#     }
# ]
#
# 🔹 **Processed Row 1333/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1334/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1335/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1336/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
# Error processing Row 1337: CUDA out of memory. Tried to allocate 74.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 18.12 MiB is free. Process 7279 has 14.72 GiB memory in use. Of the allocated memory 12.50 GiB is allocated by PyTorch, and 2.09 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
# 🔹 **Processed Row 1338/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1339/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "firewallchain {'nova-api-input:filter:ipv4': ensure => present, } firewallchain {'nova-api-forward:filter:ipv4': ensure => present, } firewallchain {'nova-api-output:filter:ipv4': ensure => present, } firewallchain {'nova-api-local:filter:ipv4': ensure => present, } firewallchain {'nova-filter-top:filter:ipv4': ensure => present, } firewallchain {'nova-api-output:nat:ipv4': ensure => present, } firewallchain {'nova-api-postrouting:nat:ipv4': ensure => present, } firewallchain {'nova-api-prerouting:nat:ipv4': ensure => present, } firewallchain {'nova-api-float-snat:nat:ipv4': ensure => present, } firewallchain {'nova-api-snat:nat:ipv4': ensure => present, } firewallchain {'nova-api-postrouting-bottom:nat:ipv4': ensure => present, }"
#     }
# ]
#
# 🔹 **Processed Row 1340/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1341/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "mellanox-plugin"
#     }
# ]
#
# 🔹 **Processed Row 1342/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "class congress { include ::congress::params }"
#     }
# ]
#
# 🔹 **Processed Row 1343/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1344/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "class { '::osnailyfacter::ssl::ssl_keys_saving' :}"
#     }
# ]
#
# 🔹 **Processed Row 1345/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "osnailyfacter/modular/./murano/keystone.pp is deprecated in mitaka and will be removed in newton. please use openstack_tasks/examples/./murano/keystone.pp"
#     }
# ]
#
# 🔹 **Processed Row 1346/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1347/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1348/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1349/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1350/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1351/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1352/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1353/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1354/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1355/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1356/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1357/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1358/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1359/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "sleep: setting => \\"
#     }
# ]
#
# 🔹 **Processed Row 1360/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1361/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "mysql_user { $user_title: password_hash => $password_hash } -> mysql_grant { \\"
#     }
# ]
#
# 🔹 **Processed Row 1362/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1363/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "osnailyfacter/modular/./openstack-network/server-nova.pp is deprecated in mitaka and will be removed in newton. please use openstack_tasks/examples/./openstack-network/server-nova.pp"
#     }
# ]
#
# 🔹 **Processed Row 1364/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1365/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1366/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1367/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1368/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "file { \\"
#     }
# ]
#
# 🔹 **Processed Row 1369/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1370/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1371/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1372/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1373/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1374/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "nova::objectstore( $enabled = true, $manage_service = true, $ensure_package = 'present', $bind_address = '0.0.0.0' ) { include ::nova::deps include ::nova::params nova::generic_service { 'objectstore': enabled => $enabled, manage_service => $manage_service, package_name => $::nova::params::objectstore_package_name, service_name => $::nova::params::objectstore_service_name, ensure_package => $ensure_package, } nova_config { 'default/s3_listen': value => $bind_address; } }"
#     }
# ]
#
# 🔹 **Processed Row 1375/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1376/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "osnailyfacter/modular/./heat/cfn_keystone.pp is deprecated in mitaka and will be removed in newton. please use openstack_tasks/examples/./heat/cfn_keystone.pp"
#     }
# ]
#
# 🔹 **Processed Row 1377/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "service { 'puppet': ensure => $ensure, enable => $enable, }"
#     }
# ]
#
# 🔹 **Processed Row 1378/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
# Error processing Row 1379: CUDA out of memory. Tried to allocate 32.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 14.12 MiB is free. Process 7279 has 14.72 GiB memory in use. Of the allocated memory 13.61 GiB is allocated by PyTorch, and 1015.32 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
# 🔹 **Processed Row 1380/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1381/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1382/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1383/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1384/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1385/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1386/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "class toplevel::mixin::releaserunner { include ::releaserunner }"
#     }
# ]
#
# 🔹 **Processed Row 1387/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1388/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1389/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1390/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1391/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1392/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1393/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "require all granted"
#     }
# ]
#
# 🔹 **Processed Row 1394/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "realize(packages::yumrepo['mig-agent']) anchor['packages::mozilla::mig_agent::begin'] -> package {'mig-agent': ensure => '20150330+e3f41a6.prod-1' } -> anchor['packages::mozilla::mig_agent::end']"
#     }
# ]
#
# 🔹 **Processed Row 1395/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1396/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "class { '::osnailyfacter::globals::globals' :}"
#     }
# ]
#
# 🔹 **Processed Row 1397/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1398/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1399/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1400/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1401/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1402/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1403/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "murano_config {'murano/url' : value => \\"
#     }
# ]
#
# 🔹 **Processed Row 1404/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "class { '::osnailyfacter::cluster_haproxy::cluster_haproxy' :} class { '::osnailyfacter::upgrade::restart_services' :}"
#     }
# ]
#
# 🔹 **Processed Row 1405/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1406/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1407/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1408/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "file { \\"
#     }
# ]
#
# 🔹 **Processed Row 1409/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1410/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1411/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "mistral::policy ( $policies = {}, $policy_path = '/etc/mistral/policy.json', ) { validate_hash($policies) openstacklib::policy::base { file_path => $policy_path, } create_resources('openstacklib::policy::base', $policies) oslo::policy {'mistral_config': policy_file => $policy_path } }"
#     }
# ]
#
# 🔹 **Processed Row 1412/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "osnailyfacter/modular/./openstack-network/agents/l3.pp is deprecated in mitaka and will be removed in newton. please use openstack_tasks/examples/./openstack-network/agents/l3.pp"
#     }
# ]
#
# 🔹 **Processed Row 1413/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1414/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1415/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1416/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1417/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1418/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1419/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "notify {"
#     }
# ]
#
# 🔹 **Processed Row 1420/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "mediawiki::extension { 'torblock': }"
#     }
# ]
#
# 🔹 **Processed Row 1421/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1422/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "cinder-manage db purge ${age} >>${destination} 2>&1"
#     }
# ]
#
# 🔹 **Processed Row 1423/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1424/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1425/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1426/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1427/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1428/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1429/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1430/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1431/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1432/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "package { \\"
#     }
# ]
#
# 🔹 **Processed Row 1433/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1434/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1435/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1436/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "keystone::resource::service_identity { 'heat': configure_user => $configure_user, configure_user_role => $configure_user_role, configure_endpoint => $configure_endpoint, configure_service => $configure_service, service_type => $service_type, service_description => $service_description, service_name => $service_name, region => $region, auth_name => $auth_name, password =>, email => $email, tenant => $tenant, public_url => $public_url, admin_url => $admin_url, internal_url => $internal_url, } if $configure_user_role { keystone_user_role["
#     },
#     {
#         "misconfigured_snippet": "keystone_user_role { $heat_stack_user_role: ensure => present, } } if $manage_heat_stack_user_role { keystone_role { $heat_stack_user_role: ensure => present, } } if $configure_delegated_roles { keystone_role { $trusts_delegated_roles: ensure => present, } }"
#     }
# ]
#
# 🔹 **Processed Row 1437/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1438/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1439/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "users::builder::extra_authorized_key {'release-runner': ; }"
#     }
# ]
#
# 🔹 **Processed Row 1440/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "packages::binscope{ packages::pkgmsi { \\"
#     }
# ]
#
# 🔹 **Processed Row 1441/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1442/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "barbican-manage db upgrade ${extra_params}"
#     }
# ]
#
# 🔹 **Processed Row 1443/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1444/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1445/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1446/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "acl { 'temp_dir_module_name': target => 'c:/temp', permissions => [ { identity => 'bob', rights => [read,execute] }, { identity => 'tim', rights => [read,execute] } ], }"
#     }
# ]
#
# 🔹 **Processed Row 1447/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "nova_config { 'libvirt/iscsi_use_multipath': value => \\"
#     },
#     {
#         "misconfigured_snippet": "nova_config { 'libvirt/hw_disk_discard': value => 'unmap' }"
#     }
# ]
#
# 🔹 **Processed Row 1448/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "barbican::keystone::notification ( $enable_keystone_notification = $::os_service_default, $keystone_notification_control_exchange = $::os_service_default, $keystone_notification_topic = $::os_service_default, $keystone_notification_allow_requeue = $::os_service_default, $keystone_notification_thread_pool_size = $::os_service_default, ) { barbican_config { 'keystone_notifications/enable': value => $enable_keystone_notification; 'keystone_notifications/control_exchange': value => $keystone_notification_control_exchange; 'keystone_notifications/topic': value => $keystone_notification_topic; 'keystone_notifications/allow_requeue': value => $keystone_notification_allow_requeue; 'keystone_notifications/thread_pool_size': value => $keystone_notification_thread_pool_size; } }"
#     }
# ]
#
# 🔹 **Processed Row 1449/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1450/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1451/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "notice('modular: mcollective.pp') $fuel_settings = parseyaml($astute_settings_yaml) class { 'fuel::mcollective': mco_host => $::fuel_settings['admin_network']['ipaddress'], mco_user => $::fuel_settings['mcollective']['user'], mco_password => $::fuel_settings['mcollective']['password'], }"
#     }
# ]
#
# 🔹 **Processed Row 1452/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "barbican_config { 'dogtag_plugin/pem_path': value => $dogtag_plugin_pem_path; 'dogtag_plugin/dogtag_host': value => $dogtag_plugin_dogtag_host; 'dogtag_plugin/dogtag_port': value => $dogtag_plugin_dogtag_port; 'dogtag_plugin/nss_db_path': value => $dogtag_plugin_nss_db_path; 'dogtag_plugin/nss_password': value => $dogtag_plugin_nss_password; 'dogtag_plugin/simple_cmc_profile': value => $dogtag_plugin_simple_cmc_profile; 'dogtag_plugin/ca_expiration_time': value => $dogtag_plugin_ca_expiration_time; 'dogtag_plugin/plugin_working_dir': value => $dogtag_plugin_plugin_working_dir; } package['dogtag-client'] -> barbican_config<||> }"
#     }
# ]
#
# 🔹 **Processed Row 1453/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1454/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "file { $vmwaretools::working_dir: ensure => directory, owner => 'root', group => 'root', mode => '0700', }"
#     }
# ]
#
# 🔹 **Processed Row 1455/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "class { '::osnailyfacter::vmware::compute_vmware' :} class { '::osnailyfacter::upgrade::restart_services' :}"
#     }
# ]
#
# 🔹 **Processed Row 1456/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1457/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "file { \\"
#     }
# ]
#
# 🔹 **Processed Row 1458/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1459/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1460/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1461/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1462/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1463/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "class toplevel::slave::qa::tps_ci inherits toplevel::slave::qa { }"
#     }
# ]
#
# 🔹 **Processed Row 1464/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1465/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1466/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1467/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1468/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "package { \\"
#     }
# ]
#
# 🔹 **Processed Row 1469/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "package { \\"
#     }
# ]
#
# 🔹 **Processed Row 1470/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "file { \\"
#     }
# ]
#
# 🔹 **Processed Row 1471/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "swift-ring-builder /etc/swift/object.builder create 18 3 1"
#     }
# ]
#
# 🔹 **Processed Row 1472/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "ironic_config { 'default/auth_strategy': value => $auth_strategy; 'default/my_ip': value => $my_ip; 'glance/glance_num_retries': value => $glance_num_retries; 'glance/glance_api_insecure': value => $glance_api_insecure;"
#     }
# ]
#
# 🔹 **Processed Row 1473/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1474/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1475/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1476/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1477/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1478/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1479/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1480/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "package { \\"
#     }
# ]
#
# 🔹 **Processed Row 1481/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1482/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "if false { } else { } if true { }"
#     }
# ]
#
# 🔹 **Processed Row 1483/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1484/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1485/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "registry::value { 'noactivedesktop': key => 'hklm\\software\\microsoft\\windows\\currentversion\\policies\\explorer', type => dword, data => '00000001', } registry::value { 'noactivedesktopchanges': key => 'hklm\\software\\microsoft\\windows\\currentversion\\policies\\explorer', type => dword, data => '00000001', } registry::value { 'forceactivedesktopon': key => 'hklm\\software\\microsoft\\windows\\currentversion\\policies\\explorer', type => dword, data => '00000000', } registry::value {'showsuperhidden': key => 'hklm\\software\\microsoft\\windows\\currentversion\\policies\\explorer', type => dword, data => '00000001', } registry::value { 'nowindowsupdate': key => 'hklm\\software\\microsoft\\windows\\currentversion\\policies\\explorer', type => dword, data => '00000001', } }]}\n\n## **Task 2: Finding Security Risks in Puppet Code**\n\n### **Description**\nYou are a **security expert specializing in Puppet configuration security**. Your task is to analyze the following Puppet code and identify **all possible security risks**.\n\n    **Puppet Script to Analyze**:\n    ```puppet\n    class disableservices::disableupdates { registry::value { 'noactivedesktop': key => 'hklm\\software\\microsoft\\windows\\currentversion\\policies\\explorer', type => dword, data => '00000001', } registry::value { 'noactivedesktopchanges': key => 'hklm\\software\\microsoft\\windows\\currentversion\\policies\\explorer', type => dword, data => '00000001', } registry::value { 'forceactivedesktopon': key => 'hklm\\software\\microsoft\\windows\\currentversion\\policies\\explorer"
#     }
# ]
#
# 🔹 **Processed Row 1486/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "cinder_config { 'default/backup_driver': value => $backup_driver; 'default/backup_ceph_conf': value => $backup_ceph_conf; 'default/backup_ceph_user': value => $backup_ceph_user; 'default/backup_ceph_chunk_size': value => $backup_ceph_chunk_size; 'default/backup_ceph_pool': value => $backup_ceph_pool; 'default/backup_ceph_stripe_unit': value => $backup_ceph_stripe_unit; 'default/backup_ceph_stripe_count': value => $backup_ceph_stripe_count; }"
#     }
# ]
#
# 🔹 **Processed Row 1487/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "class { '::openstack_tasks::murano::murano' :} class { '::osnailyfacter::upgrade::restart_services' :} class openstack::firewall {} include openstack::firewall"
#     }
# ]
#
# 🔹 **Processed Row 1488/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1489/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1490/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1491/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "class sysfs::params { $package ='sysfsutils' $service ='sysfsutils' $config_dir = '/etc/sysfs.d' }"
#     }
# ]
#
# 🔹 **Processed Row 1492/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "package { 'fcgiwrap': ensure => present, }"
#     }
# ]
#
# 🔹 **Processed Row 1493/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1494/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1495/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1496/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1497/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1498/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1499/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1500/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "package { 'ccache': ensure => '3.1.9-3moz0'; }"
#     }
# ]
#
# 🔹 **Processed Row 1501/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1502/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1503/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1504/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1505/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "osnailyfacter/modular/./ironic/ironic.pp is deprecated in mitaka and will be removed in newton. please use openstack_tasks/examples/./ironic/ironic.pp"
#     }
# ]
#
# 🔹 **Processed Row 1506/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "package { ['ruby-json', 'ruby-rest-client']: ensure => latest, }"
#     }
# ]
#
# 🔹 **Processed Row 1507/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1508/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "class { '::osnailyfacter::dns::dns_client' :}"
#     }
# ]
#
# 🔹 **Processed Row 1509/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1510/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1511/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1512/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1513/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1514/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1515/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1516/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1517/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1518/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "class role::greystuff { mediawiki::skin { 'greystuff': } }"
#     }
# ]
#
# 🔹 **Processed Row 1519/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1520/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1521/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1522/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1523/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1524/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1525/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1526/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1527/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1528/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1529/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1530/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1531/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1532/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1533/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1534/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "ironic_config { 'agent/stream_raw_images': value => $stream_raw_images; 'agent/post_deploy_get_power_state_retries': value => $post_deploy_get_power_state_retries; 'agent/post_deploy_get_power_state_retry_interval': value => $post_deploy_get_power_state_retry_interval; 'agent/deploy_logs_collect': value => $deploy_logs_collect; 'agent/deploy_logs_storage_backend': value => $deploy_logs_storage_backend; 'agent/deploy_logs_local_path': value => $deploy_logs_local_path; 'agent/deploy_logs_swift_container': value => $deploy_logs_swift_container; 'agent/deploy_logs_swift_days_to_expire': value => $deploy_logs_swift_days_to_expire; } }"
#     }
# ]
#
# 🔹 **Processed Row 1535/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1536/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1537/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1538/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1539/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "class { '::osnailyfacter::cluster_vrouter::cluster_vrouter' :} class { '::osnailyfacter::upgrade::restart_services' :}"
#     }
# ]
#
# 🔹 **Processed Row 1540/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1541/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1542/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1543/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1544/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1545/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1546/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1547/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1548/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1549/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1550/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "myfile { $file: ensure => file, mode => $mode }"
#     }
# ]
#
# 🔹 **Processed Row 1551/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "class { '::osnailyfacter::ssl::ssl_add_trust_chain' :}"
#     }
# ]
#
# 🔹 **Processed Row 1552/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1553/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1554/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1555/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1556/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1557/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "package {'sudo': ensure => present, } file { '/etc/sudoers.d/local': source => 'puppet:///modules/sudo/local', mode => '0440', }"
#     }
# ]
#
# 🔹 **Processed Row 1558/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1559/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "include ::monasca::apiserver"
#     }
# ]
#
# 🔹 **Processed Row 1560/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1561/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1562/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "case $var { \\"
#     }
# ]
#
# 🔹 **Processed Row 1563/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1564/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1565/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1566/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1567/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1568/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "file { \\"
#     }
# ]
#
# 🔹 **Processed Row 1569/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "mistral::db { $database_connection_real = pick($::mistral::database_connection,$database_connection) $database_idle_timeout_real = pick($::mistral::database_idle_timeout,$database_idle_timeout) $database_min_pool_size_real = pick($::mistral::database_min_pool_size,$database_min_pool_size) $database_max_pool_size_real = pick($::mistral::database_max_pool_size,$database_max_pool_size) $database_max_retries_real = pick($::mistral::database_max_retries,$database_max_retries) $database_retry_interval_real = pick($::mistral::database_retry_interval,$database_retry_interval) $database_max_overflow_real = pick($::mistral::database_max_overflow,$database_max_overflow) validate_re($database_connection_real, '^(sqlite|mysql(\\+pymysql)?|postgresql):\\/\\/(\\s+:\\s+@\\s+\\/\\s+)?') oslo::db {'mistral_config': connection => $database_connection_real, idle_timeout => $database_idle_timeout_real, min_pool_size => $database_min_pool_size_real, max_pool_size => $database_max_pool_size_real, max_retries => $database_max_retries_real, retry_interval => $database_retry_interval_real, max_overflow => $database_max_overflow_real, db_max_retries => $database_db_max_retries, } }"
#     }
# ]
#
# 🔹 **Processed Row 1570/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1571/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1572/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1573/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1574/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1575/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1576/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1577/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "mediawiki::extension { 'checkuser': needs_update => true, }"
#     }
# ]
#
# 🔹 **Processed Row 1578/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1579/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1580/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1581/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1582/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "nova_config { 'default/public_interface': value => $public_interface }"
#     }
# ]
#
# 🔹 **Processed Row 1583/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1584/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "aodh_config { 'api/enable_combination_alarms' : value => $enable_combination_alarms; }"
#     }
# ]
#
# 🔹 **Processed Row 1585/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1586/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1587/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1588/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1589/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1590/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "class { '::heat::db::mysql': password => 'heat', }"
#     }
# ]
#
# 🔹 **Processed Row 1591/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1592/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "nova::scheduler( $enabled = true, $manage_service = true, $ensure_package = 'present', $scheduler_driver = 'filter_scheduler', ) { include ::nova::deps include ::nova::db include ::nova::params nova::generic_service {'scheduler': enabled => $enabled, manage_service => $manage_service, package_name => $::nova::params::scheduler_package_name, service_name => $::nova::params::scheduler_service_name, ensure_package => $ensure_package, } nova_config { 'default/scheduler_driver': value => $scheduler_driver; } }"
#     }
# ]
#
# 🔹 **Processed Row 1593/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1594/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1595/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1596/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1597/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "package['postfix'] -> package['mailutils']"
#     }
# ]
#
# 🔹 **Processed Row 1598/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1599/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "osnailyfacter/modular/./roles/compute.pp is deprecated in mitaka and will be removed in newton. please use openstack_tasks/examples/./roles/compute.pp"
#     }
# ]
#
# 🔹 **Processed Row 1600/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "stage { 'network': before => stage['packagesetup']; 'packagesetup': before => stage['users']; 'users': before => stage['main']; }"
#     }
# ]
#
# 🔹 **Processed Row 1601/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1602/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1603/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "nova_config { 'default/public_interface': value => $public_interface }"
#     }
# ]
#
# 🔹 **Processed Row 1604/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1605/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1606/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1607/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1608/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1609/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "1.30"
#     }
# ]
#
# 🔹 **Processed Row 1610/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "assert { 'puppetmaster-high-security': condition => $::security::high; }"
#     }
# ]
#
# 🔹 **Processed Row 1611/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1612/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1613/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1614/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1615/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "mcx { '/groups/mcx_dock': ensure => 'absent', content => 'absent' }"
#     }
# ]
# Error processing Row 1616: CUDA out of memory. Tried to allocate 84.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 16.12 MiB is free. Process 7279 has 14.72 GiB memory in use. Of the allocated memory 13.75 GiB is allocated by PyTorch, and 865.22 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
# 🔹 **Processed Row 1617/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "class ruby::default { include ruby ruby::ruby { $ruby::default_version: } }"
#     }
# ]
# Error processing Row 1618: CUDA out of memory. Tried to allocate 18.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 16.12 MiB is free. Process 7279 has 14.72 GiB memory in use. Of the allocated memory 13.14 GiB is allocated by PyTorch, and 1.46 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
# 🔹 **Processed Row 1619/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1620/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1621/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1622/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "ceilometer_hash['enabled']"
#     }
# ]
#
# 🔹 **Processed Row 1623/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1624/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1625/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1626/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1627/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "file { 'c:/tools/vs2013': ensure => link, target => 'c:\\program files (x86)\\microsoft visual studio 12.0'; } file { 'c:/program files (x86)/microsoft visual studio 10.0/vc/bin/cvtres.exe' : ensure => file, source =>"
#     }
# ]
# ...
#     }
# ]
#
# 🔹 **Processed Row 1842/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1843/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "check_hdfs_active_namenode"
#     }
# ]
#
# 🔹 **Processed Row 1844/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1845/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "merge_yaml_settings { '1' : override_data => { 'c' => '3' }, } -> merge_yaml_settings { '2' : override_data => { 'd' => ['1','2'] }, } -> merge_yaml_settings { '3' : override_data => { 'd' => ['3','4'] }, } -> merge_yaml_settings { '4' : override_data => { 'd' => ['3','4'] }, }"
#     }
# ]
#
# 🔹 **Processed Row 1846/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1847/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1848/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1849/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1850/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1851/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "osnailyfacter/modular/./ironic/ironic-compute.pp is deprecated in mitaka and will be removed in newton. please use openstack_tasks/examples/./ironic/ironic-compute.pp"
#     }
# ]
#
# 🔹 **Processed Row 1852/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1853/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1854/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1855/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1856/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1857/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1858/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "class { '::osnailyfacter::netconfig::reserved_ports' :}"
#     }
# ]
#
# 🔹 **Processed Row 1859/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1860/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1861/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "service { 'httpd': name => 'apache2', require => class[\\"
#     }
# ]
#
# 🔹 **Processed Row 1862/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1863/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1864/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1865/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "define browsertests::bundle( $directory = $title, ) { include browsertests include ruby::default ruby::bundle { $title: directory => $directory, missing_ok => true, } }"
#     }
# ]
#
# 🔹 **Processed Row 1866/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1867/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1868/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1869/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1870/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1871/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1872/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1873/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1874/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1875/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "include ::osnailyfacter::plugins::plugins_rsync"
#     }
# ]
#
# 🔹 **Processed Row 1876/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1877/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1878/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1879/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1880/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1881/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1882/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1883/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1884/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "command => '"
#     }
# ]
#
# 🔹 **Processed Row 1885/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1886/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1887/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1888/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "create_resources('host', $hosts_spec)"
#     }
# ]
#
# 🔹 **Processed Row 1889/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1890/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1891/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1892/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "nova::availability_zone ( $default_availability_zone = $::os_service_default, $default_schedule_zone = $::os_service_default, $internal_service_availability_zone = $::os_service_default, ) { $default_availability_zone_real = pick( $::nova::compute::default_availability_zone, $default_availability_zone) $default_schedule_zone_real = pick( $::nova::compute::default_schedule_zone, $default_schedule_zone) $internal_service_availability_zone_real = pick( $::nova::compute::internal_service_availability_zone, $internal_service_availability_zone) nova_config { 'default/default_availability_zone': value => $default_availability_zone_real; 'default/default_schedule_zone': value => $default_schedule_zone_real; 'default/internal_service_availability_zone': value => $internal_service_availability_zone_real; } }"
#     }
# ]
#
# 🔹 **Processed Row 1893/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1894/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1895/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1896/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1897/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1898/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1899/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "mysql_client_name = 'percona-xtradb-cluster-client-5.6'"
#     }
# ]
#
# 🔹 **Processed Row 1900/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1901/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1902/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
# Error processing Row 1903: CUDA out of memory. Tried to allocate 274.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 270.12 MiB is free. Process 7279 has 14.47 GiB memory in use. Of the allocated memory 13.93 GiB is allocated by PyTorch, and 431.37 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
# 🔹 **Processed Row 1904/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "keystone_endpoint[\\"
#     }
# ]
#
# 🔹 **Processed Row 1905/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "class { '::osnailyfacter::openstack_haproxy::openstack_haproxy_cinder' :}"
#     }
# ]
#
# 🔹 **Processed Row 1906/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1907/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1908/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1909/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1910/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1911/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1912/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "file { \\"
#     }
# ]
#
# 🔹 **Processed Row 1913/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1914/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1915/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "notice('modular: bigswitch restart-cluster-services') include bcf::params if $bcf::params::openstack::bcf_mode == 'p-only' { include bcf::p_only::restart_cluster_services } else { include bcf::p_v::restart_cluster_services }"
#     }
# ]
#
# 🔹 **Processed Row 1916/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1917/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1918/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1919/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1920/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1921/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "mediawiki::extension { 'inputbox': }"
#     }
# ]
#
# 🔹 **Processed Row 1922/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1923/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1924/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1925/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1926/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1927/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1928/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "define oslo::messaging::default( $rpc_response_timeout = $::os_service_default, $transport_url = $::os_service_default, $control_exchange = $::os_service_default, ) { $default_options = { 'default/rpc_response_timeout' => { value => $rpc_response_timeout }, 'default/transport_url' => { value => $transport_url }, 'default/control_exchange' => { value => $control_exchange }, } create_resources($name, $default_options) }"
#     }
# ]
#
# 🔹 **Processed Row 1929/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "package { [\\"
#     }
# ]
#
# 🔹 **Processed Row 1930/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1931/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1932/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1933/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1934/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1935/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1936/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1937/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1938/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1939/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "package { 'libapache2-mod-wsgi': }"
#     }
# ]
#
# 🔹 **Processed Row 1940/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1941/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "package { \\"
#     }
# ]
#
# 🔹 **Processed Row 1942/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "object-expirer/auto_create_account_prefix: value => $auto_create_account_prefix;"
#     }
# ]
#
# 🔹 **Processed Row 1943/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1944/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1945/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1946/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "class sudo { }"
#     }
# ]
# Error processing Row 1947: CUDA out of memory. Tried to allocate 126.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 38.12 MiB is free. Process 7279 has 14.70 GiB memory in use. Of the allocated memory 14.44 GiB is allocated by PyTorch, and 135.96 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
# 🔹 **Processed Row 1948/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1949/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1950/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1951/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "diskperf -y"
#     }
# ]
#
# 🔹 **Processed Row 1952/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1953/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "sriov_nic_agent_config { 'agent/extensions': value => 'qos'; } sriov_nic_agent_config <||> ~> service['neutron-plugin-sriov-agent']"
#     }
# ]
#
# 🔹 **Processed Row 1954/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1955/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "class { '::openstack_tasks::swift::keystone' :}"
#     }
# ]
#
# 🔹 **Processed Row 1956/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "class deploystudio { include deploystudio::files }"
#     }
# ]
#
# 🔹 **Processed Row 1957/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# 🔹 **Processed Row 1958/1958** 🔹
#
# [
#     {
#         "misconfigured_snippet": "misconfigured_snippet_1"
#     }
# ]
#
# **All scripts analyzed successfully! Results saved in 'output_results.csv'**

# %%
#using starcoder2 for ansible dataset

# %%
from google.colab import drive
import pandas as pd
import torch
import json
import csv
from jsonformer import Jsonformer
from transformers import AutoModelForCausalLM, AutoTokenizer

# Mount Google Drive
drive.mount('/content/drive')

# Define CSV file path in Google Drive
csv_file_ansible = "/content/drive/My Drive/expermintstarcoder/merged_file_ansible_defect.csv"  # Input CSV file path
output_file = "/content/drive/My Drive/expermintstarcoder/merged_file_ansible_defect_output.csv"  # Output CSV file path

# Load the CSV file from Google Drive
df = pd.read_csv(csv_file_ansible)

# Check if GPU is available
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# Load model and tokenizer from Hugging Face model hub
model_name = "bigcode/starcoder2-3b"  # Replace with the correct model name

print("Loading model from Hugging Face model hub...")
model = AutoModelForCausalLM.from_pretrained(model_name, torch_dtype=torch.float16).to(device)
tokenizer = AutoTokenizer.from_pretrained(model_name)
print("Model loaded successfully!")

# Put model in evaluation mode
model.eval()

# Fix tokenizer pad token issue
tokenizer.pad_token = tokenizer.eos_token

# Define JSON Schema (Ensures long responses)
json_schema = {
    "type": "object",
    "properties": {
        "issues_found": {
            "type": "array",
            "items": {
                "type": "object",
                "properties": {
                    "misconfigured_snippet": {"type": "string"},
                }
            }
        }
    }
}

# Function to analyze Puppet misconfiguration
def analyze_misconfiguration(code_snippet):
    # Define structured prompt
    prompt = f"""
    You are a **security expert specializing in Ansible configuration security**. Your task is to analyze the following Ansible code and identify **all possible security risks**.

    **Ansible Script to Analyze**:
    ```Ansible
    {code_snippet}
    ```

    ### **Response Format if isuues found **
    Return the response in **valid JSON format**:
    ```json
    {{
      "issues_found": [
        {{
          "misconfigured_snippet": "<misconfigured_snippet_1>",

        }},
        {{
          "misconfigured_snippet": "<misconfigured_snippet_2>",

        }},
          {{
          "misconfigured_snippet": "No misconfigured_snippet Found ",

        }}

      ]
    }}

    ```

    ### **Instructions**
    - **Only report security risks**. Ignore syntax or general best practices.
    - If there are **multiple risks**, list **all** of them.








    - **Return ONLY JSON** (without extra text or explanations).
    """

    max_length = min(len(tokenizer.encode(prompt)), 6000)

    # Tokenize input and move to GPU (Allowing longer input)
    inputs = tokenizer(
        prompt,
        return_tensors="pt",
        max_length=max_length,
        truncation=True,
        padding="max_length"
    ).to(device)

    # Generate structured output using Jsonformer with high token limit
    with torch.no_grad():
        structured_output = Jsonformer(
            model,
            tokenizer,
            json_schema=json_schema,
            prompt=prompt,
            max_string_token_length=max_length,
        )

    return structured_output()

# Open CSV file and write header only once
with open(output_file, mode="w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["Added_lines_fixing_commit", "Added_lines_bug_inducing_commit", "Fixing_Script_MisconfigurationFoundbyLLM", "Bug_Inducing_Script_MisconfigurationFoundbyLLM"])

# Process each row and save immediately after processing
for index, row in df.iterrows():
    fixing_commit_code = str(row.get("Added_lines_fixing_commit", "")).strip()
    bug_inducing_commit_code = str(row.get("Added_lines_bug_inducing_commit", "")).strip()

    if not fixing_commit_code and not bug_inducing_commit_code:
        print(f"Skipping Row {index + 1} (Empty Scripts)")
        continue

    try:
        # Analyze fixing commit (Added_lines_fixing_commit)
        result_fixing = analyze_misconfiguration(fixing_commit_code)
        issues_fixing = result_fixing.get("issues_found", [])

        # Misconfigured snippets from fixing commit
        fixing_misconfigured_snippets = ", ".join([issue.get("misconfigured_snippet", "No issues detected") for issue in issues_fixing]) if issues_fixing else "No issues detected"

        # Analyze bug-inducing commit (Added_lines_bug_inducing_commit)
        result_bug_inducing = analyze_misconfiguration(bug_inducing_commit_code)
        issues_bug_inducing = result_bug_inducing.get("issues_found", [])

        # Misconfigured snippets from bug-inducing commit
        bug_inducing_misconfigured_snippets = ", ".join([issue.get("misconfigured_snippet", "No issues detected") for issue in issues_bug_inducing]) if issues_bug_inducing else "No issues detected"

        # Write results for the same row with both fixing and bug-inducing commit analysis
        with open(output_file, mode="a", newline="", encoding="utf-8") as f:
            writer = csv.writer(f)
            writer.writerow([fixing_commit_code, bug_inducing_commit_code, fixing_misconfigured_snippets, bug_inducing_misconfigured_snippets])

        # Print result
        print(f"\n🔹 **Processed Row {index + 1}/{len(df)}** 🔹")
        print(f"Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): {fixing_misconfigured_snippets}")
        print(f"Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): {bug_inducing_misconfigured_snippets}")

    except Exception as e:
        print(f"Error processing Row {index + 1}: {e}")

print("\n**All scripts analyzed successfully! Results saved in 'output_results.csv'**")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Using device: cuda
# Loading model from Hugging Face model hub...
# Model loaded successfully!
#
# 🔹 **Processed Row 1/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): command: php occ config:system:set {{ item.name }} --value={{ item.value }}
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 2/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): when: (not _nextcloud_conf.stat.exists) or (_nextcloud_configured.rc is defined and _nextcloud_configured.rc!= 0)
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): check_mode: no\nwhen: _nextcloud_configured.rc!= 0\n
#
# 🔹 **Processed Row 3/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): when: (nc_sudo_installed_result.rc is defined) and (nc_sudo_installed_result.rc!= 0)
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 4/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 5/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 6/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 7/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 8/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 9/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): owner: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 10/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): http://localhost:{{ nexus_default_port }}{{ nexus_default_context_path }}service/siesta/rest/v1/script/{{ item }}
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 11/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 12/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 13/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): VS code integration has failed in provisioner/roles/code_server/tasks/main.yml
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 14/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): command: systemctl daemon-reload
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): systemd: daemon-reload: yes
#
# 🔹 **Processed Row 15/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): copy: src={{ caddy_home }}/caddy dest=/usr/bin/ mode=0755 remote_src=True
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): unarchive: src={{ caddy_home }}/caddy.tar.gz dest={{ caddy_home }} copy=no
#
# 🔹 **Processed Row 16/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): misconfigured_snippet_1
#
# 🔹 **Processed Row 17/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): psql {{item.name}} -c 'CREATE EXTENSION IF NOT EXISTS uuid-ossp;'
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 18/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 19/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 20/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 21/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 22/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 23/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): export NATIVE_SPEC=\
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): export IP_ADDRESS=`curl icanhazip.com`
# Error processing Row 24: CUDA out of memory. Tried to allocate 26.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 4.12 MiB is free. Process 57335 has 14.73 GiB memory in use. Of the allocated memory 14.40 GiB is allocated by PyTorch, and 218.95 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Error processing Row 25: CUDA out of memory. Tried to allocate 68.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 42.12 MiB is free. Process 57335 has 14.70 GiB memory in use. Of the allocated memory 14.40 GiB is allocated by PyTorch, and 172.76 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
# 🔹 **Processed Row 26/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 27/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): service-url: {{ bootadmin_client_base_url | default('${serverURL}/') }}{{ userdetails_context_path | default('userdetails') }}\n        management-url: {{ bootadmin_client_base_url | default('${serverURL}/') }}{{ userdetails_context_path | default('userdetails') }}/status
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 28/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): sed -i's|JAVA_VERSION=8u171|JAVA_VERSION=8u181|' oracle-java8-installer.*
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): sed -i's|JAVA_VERSION=8u161|JAVA_VERSION=8u172|' oracle-java8-installer.*
#
# 🔹 **Processed Row 29/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 30/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 31/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 32/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 33/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): when: elasticsearch_proxy
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): when: elasticsearch_proxy | bool == True
#
# 🔹 **Processed Row 34/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 35/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): webapi_war_url: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 36/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): webapi_war_url: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 37/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 38/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): when: upgrade_check_script.stdout == \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 39/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 40/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 41/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 42/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): loop: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 43/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): advanced_dhcp_server_role_version: 1.0.4
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 44/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): dhcp_server_role_version: 1.0.7
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): dhcp_server_role_version: 1.0.6
#
# 🔹 **Processed Row 45/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): dhcp_server_role_version: 1.0.4
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): role_version: 1.0.4
#
# 🔹 **Processed Row 46/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): lineinfile █ Configure root color based on iceberg number
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): lineinfile: path: /root/.bashrc line: 'PS1=\
#
# 🔹 **Processed Row 47/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): service █ Restart dhcp server
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 48/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): aws_access_key: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): aws_access_key: \
# Error processing Row 49: CUDA out of memory. Tried to allocate 106.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 18.12 MiB is free. Process 57335 has 14.72 GiB memory in use. Of the allocated memory 14.47 GiB is allocated by PyTorch, and 124.74 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
# 🔹 **Processed Row 50/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): when: node_exists['failed'] is defined and uri_hostname == 'localhost' and virt_type == \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 51/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 52/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): python2-dnf
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Error processing Row 53: CUDA out of memory. Tried to allocate 20.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 16.12 MiB is free. Process 57335 has 14.72 GiB memory in use. Of the allocated memory 14.28 GiB is allocated by PyTorch, and 323.21 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
# 🔹 **Processed Row 54/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): admin_username: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Error processing Row 55: CUDA out of memory. Tried to allocate 32.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 32.12 MiB is free. Process 57335 has 14.71 GiB memory in use. Of the allocated memory 14.10 GiB is allocated by PyTorch, and 490.11 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
# 🔹 **Processed Row 56/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 57/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 58/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): address_prefixes: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 59/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): copy: src=fetch/{{ fsid }}/etc/ceph/radosgw.gateway.keyring dest=/etc/ceph/radosgw.gateway.keyring owner=root group=root mode=600
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 60/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): copy: >
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 61/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): with_items: {{ groups.get(mon_group_name, []) }}
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 62/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): with_items: {{ groups.get(mon_group_name, []) }}
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 63/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): failed_when: false
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 64/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): name: install nss-tools on redhat
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 65/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): name: '{{ ntp_service_name }}'
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): misconfigured_snippet_1
#
# 🔹 **Processed Row 66/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 67/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 68/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 69/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): with_items: {{ groups.get(mds_group_name, []) }}
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 70/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): with_items: {{ groups.get(mds_group_name, []) }}
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 71/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): ceph_mon_docker_tag: latest
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): ceph_osd_docker_tag: latest
#
# 🔹 **Processed Row 72/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): src=s3gw.fcgi.j2
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): misconfigured_snippet_1
#
# 🔹 **Processed Row 73/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 74/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 75/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 76/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 77/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): dest: /etc/default/ceph
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): misconfigured_snippet_1
#
# 🔹 **Processed Row 78/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 79/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 80/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 81/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): author: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 82/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): restart win zabbix agent
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): restart win zabbix-agent
#
# 🔹 **Processed Row 83/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): nan
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): chain: INPUT\nsource: \
#
# 🔹 **Processed Row 84/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): dest: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 85/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): when: es_start_service and (es_enable_xpack and \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 86/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): lineinfile: dest=/etc/sysconfig/elasticsearch regexp=\
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 87/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): mode: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 88/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): no_log: True
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): no_log: True
#
# 🔹 **Processed Row 89/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): author: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): author: \
#
# 🔹 **Processed Row 90/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): set -o pipefail;
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 91/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): service: name: rsyslog enabled: yes - ubuntu1804cis_syslog == \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): command: \
# Error processing Row 92: CUDA out of memory. Tried to allocate 20.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 16.12 MiB is free. Process 57335 has 14.72 GiB memory in use. Of the allocated memory 14.12 GiB is allocated by PyTorch, and 488.46 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Error processing Row 93: CUDA out of memory. Tried to allocate 36.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 32.12 MiB is free. Process 57335 has 14.71 GiB memory in use. Of the allocated memory 14.22 GiB is allocated by PyTorch, and 372.54 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
# 🔹 **Processed Row 94/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): file: path: /etc/nginx/sites-enabled/default state: absent notify: Restart nginx
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 95/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 96/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 97/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 98/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 99/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): min_ansible_version: 2.3
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): min_ansible_version: 2.2
#
# 🔹 **Processed Row 100/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): misconfigured_snippet_1
#
# 🔹 **Processed Row 101/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 102/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): misconfigured_snippet_1
#
# 🔹 **Processed Row 103/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 104/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): sops: BrokerMemory: https://github.com/integr8ly/integreatly-help/blob/master/sops/AMQOnline_BrokerMemory.asciidoc
#
# 🔹 **Processed Row 105/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 106/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): oc delete clusterroles.rbac.authorization.k8s.io managed-service
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 107/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): nan
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 108/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): oc get secret {{ launcher_sso_keycloak_client_id }}-client -n {{ rhsso_namespace }} -o template --template=\{\{.data.secret\}\}
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Error processing Row 109: CUDA out of memory. Tried to allocate 20.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 14.12 MiB is free. Process 57335 has 14.72 GiB memory in use. Of the allocated memory 14.21 GiB is allocated by PyTorch, and 400.42 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Error processing Row 110: CUDA out of memory. Tried to allocate 40.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 34.12 MiB is free. Process 57335 has 14.71 GiB memory in use. Of the allocated memory 14.51 GiB is allocated by PyTorch, and 72.98 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
# 🔹 **Processed Row 111/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): oc process -n {{ launcher_namespace }} -f {{ launcher_template }} --param=CREATOR_BACKEND_MEMORY_REQUEST=10Mi --param=LAUNCHER_MISSIONCONTROL_OPENSHIFT_USERNAME= --param=LAUNCHER_MISSIONCONTROL_OPENSHIFT_PASSWORD= --param=LAUNCHER_MISSIONCONTROL_OPENSHIFT_API_URL= --param=LAUNCHER_MISSIONCONTROL_OPENSHIFT_CONSOLE_URL= --param=LAUNCHER_KEYCLOAK_URL=https://{{ launcher_sso_route }}/auth --param=LAUNCHER_KEYCLOAK_REALM={{ launcher_sso_realm }} --param=LAUNCHER_KEYCLOAK_CLIENT_ID=launcher-public --param=LAUNCHER_BOOSTER_CATALOG_REPOSITORY={{ launcher_catalog_git_repo }} --param=LAUNCHER_BOOSTER_CATALOG_REF={{ launcher_catalog_git_ref }} --param=FRONTEND_IMAGE_TAG={{ launcher_frontend_image_tag }} --param=BACKEND_IMAGE_TAG={{ launcher_backend_image_tag }} | oc create -n {{ launcher_namespace }} -f -
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 112/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): nan
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 113/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 114/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): nan
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): when: - user_rhsso | default(true) | bool - mdc | default(true) | bool
#
# 🔹 **Processed Row 115/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 116/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): loop: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 117/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): node_ip_address: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 118/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 119/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): nan
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): misconfigured_snippet_1
#
# 🔹 **Processed Row 120/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): when: 'pve-no-subscription' in proxmox_repository_line
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 121/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 122/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 123/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 124/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): become: yes
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): misconfigured_snippet_1
#
# 🔹 **Processed Row 125/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): pkg: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): when: ansible_lsb.major_release|int >= 8
#
# 🔹 **Processed Row 126/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): file: dest={{ solr_config_dir }} state=directory group=solr mode=\
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 127/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 128/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): service: name: iptables state: restarted enabled: yes
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): shell: systemctl enable --now iptables
# Error processing Row 129: CUDA out of memory. Tried to allocate 20.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 10.12 MiB is free. Process 57335 has 14.73 GiB memory in use. Of the allocated memory 14.10 GiB is allocated by PyTorch, and 518.76 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
# 🔹 **Processed Row 130/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): when: ansible_distribution in ['Ubuntu', 'Debian']
#
# 🔹 **Processed Row 131/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 132/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Error processing Row 133: CUDA out of memory. Tried to allocate 30.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 24.12 MiB is free. Process 57335 has 14.71 GiB memory in use. Of the allocated memory 14.10 GiB is allocated by PyTorch, and 497.10 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
# 🔹 **Processed Row 134/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 135/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): command: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 136/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 137/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): springapp_min_heapsize: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 138/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): springapp_min_heapsize: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): springapp_heapsize: \
#
# 🔹 **Processed Row 139/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): springapp_min_heapsize: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 140/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): user: name=authz-server home={{ authz_server_dir }} shell=/sbin/nologin
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 141/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): springapp_min_heapsize: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 142/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): springapp_min_heapsize: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): springapp_heapsize: \
#
# 🔹 **Processed Row 143/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): springapp_min_heapsize: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 144/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): service: name=authz-admin state=restarted sleep=45
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): service: name=authz-admin state=restarted sleep=45
# Error processing Row 145: CUDA out of memory. Tried to allocate 90.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 42.12 MiB is free. Process 57335 has 14.70 GiB memory in use. Of the allocated memory 14.53 GiB is allocated by PyTorch, and 39.32 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
# 🔹 **Processed Row 146/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): springapp_min_heapsize: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 147/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): springapp_min_heapsize: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): springapp_heapsize: \
#
# 🔹 **Processed Row 148/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): springapp_min_heapsize: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 149/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 150/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): misconfigured_snippet_1
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 151/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 152/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): when: not registries_vault.stat.exists
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 153/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): OPTIONS='--selinux-enabled --insecure-registry 172.30.0.0/16'
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 154/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 155/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 156/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): misconfigured_snippet_1
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 157/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): misconfigured_snippet_1
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 158/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): misconfigured_snippet_1
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 159/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): misconfigured_snippet_1
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 160/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Error processing Row 161: CUDA out of memory. Tried to allocate 2.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 2.12 MiB is free. Process 57335 has 14.74 GiB memory in use. Of the allocated memory 14.32 GiB is allocated by PyTorch, and 294.33 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Error processing Row 162: CUDA out of memory. Tried to allocate 20.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 18.12 MiB is free. Process 57335 has 14.72 GiB memory in use. Of the allocated memory 13.91 GiB is allocated by PyTorch, and 697.46 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Error processing Row 163: CUDA out of memory. Tried to allocate 2.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 2.12 MiB is free. Process 57335 has 14.74 GiB memory in use. Of the allocated memory 14.02 GiB is allocated by PyTorch, and 602.77 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
# 🔹 **Processed Row 164/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): when: inventory_hostname in groups['glance-api']
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 165/308** 🔹
# ...
#
# 🔹 **Processed Row 253/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 254/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Error processing Row 255: CUDA out of memory. Tried to allocate 42.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 34.12 MiB is free. Process 57335 has 14.71 GiB memory in use. Of the allocated memory 13.71 GiB is allocated by PyTorch, and 884.91 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
# 🔹 **Processed Row 256/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): OS::TripleO::Galera::Net::SoftwareConfig: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 257/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): cp {{ base_image_path }}/{{ base_image }} {{ base_image_path }}/{{ node_image }}
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 258/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 259/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 260/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): when: 'virthost' in groups
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): when: \
# Error processing Row 261: CUDA out of memory. Tried to allocate 20.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 6.12 MiB is free. Process 57335 has 14.73 GiB memory in use. Of the allocated memory 14.12 GiB is allocated by PyTorch, and 493.43 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
# 🔹 **Processed Row 262/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): test -e.venv/bin/activate && source.venv/bin/activate
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 263/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): path: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 264/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 265/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 266/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 267/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 268/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Error processing Row 269: CUDA out of memory. Tried to allocate 20.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 14.12 MiB is free. Process 57335 has 14.72 GiB memory in use. Of the allocated memory 14.15 GiB is allocated by PyTorch, and 454.84 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
# 🔹 **Processed Row 270/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): when: gitlab_runner_registration_token | length > 0  # Ensure value is set
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Error processing Row 271: CUDA out of memory. Tried to allocate 20.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 8.12 MiB is free. Process 57335 has 14.73 GiB memory in use. Of the allocated memory 14.14 GiB is allocated by PyTorch, and 472.53 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
# 🔹 **Processed Row 272/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 273/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): insertafter: '^\s*url ='
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 274/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): dest: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 275/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 276/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): file:  CentOS-Base
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Error processing Row 277: CUDA out of memory. Tried to allocate 20.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 10.12 MiB is free. Process 57335 has 14.73 GiB memory in use. Of the allocated memory 14.14 GiB is allocated by PyTorch, and 470.32 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
# 🔹 **Processed Row 278/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 279/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): misconfigured_snippet_1
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 280/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 281/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): project_subtree: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): project_subtree: \
#
# 🔹 **Processed Row 282/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): when: sensu_redis_server\nwhen: sensu_rabbitmq_server
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 283/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): enabled: yes
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 284/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 285/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): sb-2.1.x
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 286/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 287/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): changed_when: - splunk_cluster_bundle_result.stdout.find('Applying')!= -1 - splunk_cluster_bundle_result.stdout.find('bundle')!= -1
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 288/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 289/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 290/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): path: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 291/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 292/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): port: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): port: 8089
#
# 🔹 **Processed Row 293/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): license: MIT
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 294/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): service: name={{openvpn_service}} state=restarted
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 295/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 296/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): when: threatstack_hostname and threatstack_policy
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 297/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): secret: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 298/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 299/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 300/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 301/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): mode: 0644\ngroup: 'root'\nowner: 'root'
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): mode: 0600
#
# 🔹 **Processed Row 302/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 303/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): when: ruleset.install_scripts and install_rulesets
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): when: ruleset.install_scripts == \
#
# 🔹 **Processed Row 304/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 305/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): wazuh_manager_config.cluster.node_type == \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): when:        - wazuh_manager_config.cluster.node_type == \
#
# 🔹 **Processed Row 306/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 307/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): od_node_name: \
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# 🔹 **Processed Row 308/308** 🔹
# Fixing commit misconfiguration (Fixing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
# Bug-inducing commit misconfiguration (Bug_Inducing_Script_MisconfigurationFoundbyLLM): No misconfigured_snippet Found
#
# **All scripts analyzed successfully! Results saved in 'output_results.csv'**

# %%
#Adding labels to Ansible script after llm prompting
import pandas as pd
import numpy as np

def create_misconfiguration_label(df, column_name, label_column_name):
    """
    Create a new label column based on the misconfiguration column.
    - If misconfiguration is found, label = 1.
    - If no misconfiguration is found, label = 0.
    """
    # Apply logic to create a new label column
    df[label_column_name] = df[column_name].apply(
        lambda x: 1 if str(x).strip() not in ["No misconfigured_snippet Found", "misconfigured_snippet_1", "0", ""] else 0
    )
    return df

# Load your CSV file
df = pd.read_csv("/content/drive/My Drive/expermintstarcoder/imp/merged_file_ansible_defect_output_llm.csv")

# Create new label columns based on existing misconfiguration columns
df = create_misconfiguration_label(df, "Fixing_Script_MisconfigurationFoundbyLLM", "Fixing_Script_MisconfigurationFoundbyLLM_Label")
df = create_misconfiguration_label(df, "Bug_Inducing_Script_MisconfigurationFoundbyLLM", "Bug_Inducing_Script_MisconfigurationFoundbyLLM_Label")

# Save the DataFrame with the new label columns
df.to_csv("/content/drive/My Drive/expermintstarcoder/imp/merged_file_ansible_llm_labeld.csv", index=False)

print("New label columns created and saved successfully!")
# Out:
# New label columns created and saved successfully!

# %%
def clean_code(code):
    """Remove empty lines and lines with only spaces."""
    return "\n".join([line for line in code.splitlines() if line.strip()])

# Process each row and save immediately after processing
for index, row in df.iterrows():
    # Clean the code snippets by removing empty lines
    fixing_commit_code = clean_code(str(row.get("Added_lines_fixing_commit", "")).strip())
    bug_inducing_commit_code = clean_code(str(row.get("Added_lines_bug_inducing_commit", "")).strip())

    if not fixing_commit_code and not bug_inducing_commit_code:
        print(f"Skipping Row {index + 1} (Empty Scripts)")
        continue

# %%
# metrics accuracy for puppet dataset
import pandas as pd
from sklearn.metrics import precision_recall_fscore_support, accuracy_score

# Load your dataset
df = pd.read_csv("/content/drive/My Drive/expermintstarcoder/imp/puppet_labeld.csv")

# True labels (the actual labels from your dataset)
true_labels = df['Label']  # Adjust this to match the column name for true labels

# Predicted labels (from your model)
predicted_labels = df['Misconfiguration_Found_LLM_Label']  # Adjust this to match the column name for predicted labels

# Calculate accuracy
accuracy = accuracy_score(true_labels, predicted_labels)

# Calculate precision, recall, and F1-score
precision, recall, f1, _ = precision_recall_fscore_support(
    true_labels,  # True labels
    predicted_labels,  # Predicted labels
    average='binary',  # We are working with a binary classification (0 or 1)
    zero_division=0 , # To avoid division by zero errors if there are no predicted positives
     pos_label=0,
)

# Print out the results
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
# Out:
# Accuracy: 0.4374
# Precision: 0.4254
# Recall: 0.7062
# F1-Score: 0.5310

# %%
#to be removed or reviewed

# %%
import pandas as pd
from sklearn.metrics import precision_recall_fscore_support, accuracy_score

# Load your dataset
df = pd.read_csv("/content/drive/My Drive/expermintstarcoder/imp/puppet_labeld.csv")

# True labels (the actual labels from your dataset)
true_labels = df['Label']  # Adjust this to match the column name for true labels

# Predicted labels (from your model)
predicted_labels = df['Misconfiguration_Found_LLM_Label']  # Adjust this to match the column name for predicted labels

# Temporarily filter the DataFrame to keep only rows where Label is 1 (misconfiguration)
df_filtered = df[true_labels == 1]

# Step 3: Re-calculate accuracy, precision, recall, and F1-score based only on rows with Label = 1
true_labels_filtered = df_filtered['Label']
predicted_labels_filtered = df_filtered['Misconfiguration_Found_LLM_Label']

# Calculate accuracy (for misconfigurations)
accuracy = accuracy_score(true_labels_filtered, predicted_labels_filtered)

# Calculate precision, recall, and F1-score for misconfigurations (1 as positive class)
precision, recall, f1, _ = precision_recall_fscore_support(
    true_labels_filtered,  # True labels for misconfigurations
    predicted_labels_filtered,  # Predicted labels for misconfigurations
    average='binary',  # Binary classification (0 or 1)
    pos_label=1,  # Treat '1' (misconfiguration) as the positive class
    zero_division=0  # Handle division by zero errors if no predicted positives
)

# Print out the results
print(f"Accuracy (for misconfigurations): {accuracy:.4f}")
print(f"Precision (for misconfigurations): {precision:.4f}")
print(f"Recall (for misconfigurations): {recall:.4f}")
print(f"F1-Score (for misconfigurations): {f1:.4f}")
# Out:
# Accuracy (for misconfigurations): 0.2167
# Precision (for misconfigurations): 1.0000
# Recall (for misconfigurations): 0.2167
# F1-Score (for misconfigurations): 0.3561

# %%
#this the matrics for Ansible using starcoder2-3

import pandas as pd
from sklearn.metrics import precision_recall_fscore_support

# Load the dataset
df = pd.read_csv('/content/drive/My Drive/expermintstarcoder/merged_with_labels.csv')

# Predicted labels for Fixing Script Misconfigurations
fixing_predicted_labels = df['Fixing_Script_MisconfigurationFoundbyLLM_Label']

# Predicted labels for Bug-Inducing Script Misconfigurations
bug_inducing_predicted_labels = df['Bug_Inducing_Script_MisconfigurationFoundbyLLM_Label']

# Actual labels for Added_lines_fixing_commit and Added_lines_bug_inducing_commit
# Added_lines_fixing_commit is always 1 (Fixing Script Misconfigurations)
# Added_lines_bug_inducing_commit is always 0 (Bug-Inducing Script Misconfigurations)
true_fixing_labels = [1] * len(df)  # All are 1 for fixing misconfigurations
true_bug_inducing_labels = [0] * len(df)  # All are 0 for bug-inducing misconfigurations

# Calculate Precision, Recall, and F1-Score for Fixing Script Misconfigurations
fixing_precision, fixing_recall, fixing_f1, _ = precision_recall_fscore_support(
    true_fixing_labels,  # True labels for fixing misconfigurations (always 1)
    fixing_predicted_labels,
    average='binary',
    zero_division=0  # Handle division by zero if no true positives or false negatives
)

# Calculate Precision, Recall, and F1-Score for Bug-Inducing Script Misconfigurations
# Here, we set pos_label=0 to treat 0 as the positive class
bug_inducing_precision, bug_inducing_recall, bug_inducing_f1, _ = precision_recall_fscore_support(
    true_bug_inducing_labels,  # True labels for bug-inducing misconfigurations (always 0)
    bug_inducing_predicted_labels,
    average='binary',
    zero_division=0,  # Handle division by zero if no true positives or false negatives
    pos_label=0  # Treat 0 as the positive class for Bug-Inducing
)

# Overall F1-score (average of both fixing and bug-inducing F1 scores)
overall_f1 = (fixing_f1 + bug_inducing_f1) / 2

# Overall Recall (average of both fixing and bug-inducing recall scores)
overall_recall = (fixing_recall + bug_inducing_recall) / 2

# Accuracy for Fixing Script Misconfigurations
fixing_accuracy = (fixing_predicted_labels == true_fixing_labels).sum() / len(df)

# Accuracy for Bug-Inducing Script Misconfigurations
bug_inducing_accuracy = (bug_inducing_predicted_labels == true_bug_inducing_labels).sum() / len(df)

# Print out the metrics for Fixing Script Misconfigurations
print(f"Precision for Fixing Script Misconfigurations: {fixing_precision:.4f}")
print(f"Recall for Fixing Script Misconfigurations: {fixing_recall:.4f}")
print(f"F1-Score for Fixing Script Misconfigurations: {fixing_f1:.4f}")
print(f"Accuracy for Fixing Script Misconfigurations: {fixing_accuracy:.4f}")

# Print out the metrics for Bug-Inducing Script Misconfigurations
print(f"Precision for Bug-Inducing Script Misconfigurations: {bug_inducing_precision:.4f}")
print(f"Recall for Bug-Inducing Script Misconfigurations: {bug_inducing_recall:.4f}")
print(f"F1-Score for Bug-Inducing Script Misconfigurations: {bug_inducing_f1:.4f}")
print(f"Accuracy for Bug-Inducing Script Misconfigurations: {bug_inducing_accuracy:.4f}")

# Print Overall Metrics
print(f"Overall F1-Score: {overall_f1:.4f}")
print(f"Overall Recall: {overall_recall:.4f}")
# Out:
# Precision for Fixing Script Misconfigurations: 1.0000
# Recall for Fixing Script Misconfigurations: 0.5292
# F1-Score for Fixing Script Misconfigurations: 0.6921
# Accuracy for Fixing Script Misconfigurations: 0.5292
# Precision for Bug-Inducing Script Misconfigurations: 1.0000
# Recall for Bug-Inducing Script Misconfigurations: 0.8613
# F1-Score for Bug-Inducing Script Misconfigurations: 0.9255
# Accuracy for Bug-Inducing Script Misconfigurations: 0.8613
# Overall F1-Score: 0.8088
# Overall Recall: 0.6953

# %%
# !pip install jsonformer
# Out:
# Collecting jsonformer
#   Downloading jsonformer-0.12.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting termcolor<3.0.0,>=2.3.0 (from jsonformer)
#   Downloading termcolor-2.5.0-py3-none-any.whl.metadata (6.1 kB)
# Downloading jsonformer-0.12.0-py3-none-any.whl (6.6 kB)
# Downloading termcolor-2.5.0-py3-none-any.whl (7.8 kB)
# Installing collected packages: termcolor, jsonformer
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 3.1.0
#     Uninstalling termcolor-3.1.0:
#       Successfully uninstalled termcolor-3.1.0
# Successfully installed jsonformer-0.12.0 termcolor-2.5.0

# %%
from huggingface_hub import login
login(token="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")

# %%
# !pip install bitsandbytes
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: torch<3,>=2.0 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.6.0+cu124)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3,>=2.0->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3,>=2.0->bitsandbytes) (3.0.2)
# Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl (76.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 11.6 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 125.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 94.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 64.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 83.8 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, bitsandbytes
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed bitsandbytes-0.45.5 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
# !pip install transformers==4.48.3
# Out:
# Collecting transformers==4.48.3
#   Downloading transformers-4.48.3-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (0.31.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers==4.48.3) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers==4.48.3) (4.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers==4.48.3) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.48.3) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.48.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.48.3) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.48.3) (2025.4.26)
# Downloading transformers-4.48.3-py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 94.6 MB/s eta 0:00:00
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.51.3
#     Uninstalling transformers-4.51.3:
#       Successfully uninstalled transformers-4.51.3
# Successfully installed transformers-4.48.3

# %%
# !pip install torch==2.5.1 torchvision==0.20.1
# Out:
# Collecting torch==2.5.1
#   Downloading torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting torchvision==0.20.1
#   Downloading torchvision-0.20.1-cp311-cp311-manylinux1_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (12.4.127)
# Collecting triton==3.1.0 (from torch==2.5.1)
#   Downloading triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (1.13.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision==0.20.1) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision==0.20.1) (11.2.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch==2.5.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.5.1) (3.0.2)
# Downloading torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl (906.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.5/906.5 MB 1.1 MB/s eta 0:00:00
# Downloading torchvision-0.20.1-cp311-cp311-manylinux1_x86_64.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 52.8 MB/s eta 0:00:00
# Downloading triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 3.3 MB/s eta 0:00:00
# Installing collected packages: triton, torch, torchvision
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0+cu124
#     Uninstalling torch-2.6.0+cu124:
#       Successfully uninstalled torch-2.6.0+cu124
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.21.0+cu124
#     Uninstalling torchvision-0.21.0+cu124:
#       Successfully uninstalled torchvision-0.21.0+cu124
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.6.0+cu124 requires torch==2.6.0, but you have torch 2.5.1 which is incompatible.
# Successfully installed torch-2.5.1 torchvision-0.20.1 triton-3.1.0

# %%
import pandas as pd
import torch
import json
import csv
from transformers import AutoModelForCausalLM, AutoTokenizer,BitsAndBytesConfig
from jsonformer import Jsonformer
from google.colab import drive
import torch
import sys
import os
# ========== 1. Mount Google Drive ==========

# ========== 2. Paths ==========
drive.mount('/content/drive')

# ========== 3. File Paths ==========
drive_folder = '/content/drive/MyDrive/expermintstarcoder'
input_file = os.path.join(drive_folder, 'imp/merged_file_ansible.csv')

output_file = os.path.join(drive_folder, 'final-ansible_dataset_befor_varification_starcoder2.csv')



# ========== 4. Load Model & Tokenizer ==========
model_name = "bigcode/starcoder2-7b"
device = "cuda" if torch.cuda.is_available() else "cpu"

# ========== 4. Load Model & Tokenizer ==========
print("Loading model...")
bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_use_double_quant=True,
        bnb_4bit_quant_type="nf4"
    )

model = AutoModelForCausalLM.from_pretrained(
        model_name,
        device_map="auto",
        quantization_config=bnb_config
    )
tokenizer = AutoTokenizer.from_pretrained(model_name)

tokenizer.add_eos_token = True
if '<pad>' not in tokenizer.get_vocab():
        tokenizer.add_special_tokens({"pad_token": "<pad>"})
model.resize_token_embeddings(len(tokenizer))
model.config.pad_token_id = tokenizer.pad_token_id

if tokenizer.eos_token is None:
   tokenizer.eos_token = "[EOS]"

model.eval()
# ========== 5. Define JSON Schema ==========
json_schema = {
    "type": "object",
    "properties": {
        "issues_found": {
            "type": "array",
            "items": {
                "type": "object",
                "properties": {
                    "misconfigured_snippet": {"type": "string"},
                    "related_cwe": {"type": "string"},
                }
            }
        },
        "misconfiguration_label": {"type": "string"}
    }
}

# ========== 6. Misconfiguration Analyzer ==========
def analyze_misconfiguration(code_snippet):
    prompt = f"""
    You are a security expert specializing in Ansible configuration security.
    Your task is to analyze the following Ansible playbook/task and identify only critical security misconfigurations that could lead to vulnerabilities and have a real CWE ID.
    Focus only on the available code and avoid making assumptions about unavailable details.

    Ansible Playbook to Analyze:
    ```yaml
    {code_snippet}
    ```

    Response Format:
    Return the response in **valid JSON format**:

    - If there are critical issues:
    ```json
    {{
      "issues_found": [
        {{
          "misconfigured_snippet": "<actual misconfigured code snippet>",
          "related_cwe": "<CWE-ID>"
        }}
      ],
      "misconfiguration_label": 1
    }}
    ```

    - If there are NO critical issues:
    ```json
    {{
      "issues_found": [],
      "misconfiguration_label": 0
    }}
    ```

    Instructions:
    - Only list real misconfigurations tied to known CWE IDs.
    - Do NOT insert "N/A".
    - Do not include syntax errors.
    - If no critical misconfiguration is found, return an empty issues_found array.
    """
    truncated_prompt = tokenizer.decode(
    tokenizer.encode(prompt, max_length=2000, truncation=True),

    )

    structured_output = Jsonformer(
        model=model,
        tokenizer=tokenizer,
        json_schema=json_schema,
        prompt=truncated_prompt,
        max_string_token_length=300,
    )

    return structured_output()


# ========== 7. Write CSV ==========
# Remove output file if it exists

chunksize = 5  # You can adjust this
csv_reader = pd.read_csv(input_file, chunksize=chunksize)

with open(output_file, mode='w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow([
        "Added_lines_fixing_commit",
        "Added_lines_bug_inducing_commit",
        "Fixing_Script_Misconfiguration_Label",
        "Fixing_Script_MisconfigurationFoundbyLLM",
        "Fixing_Script_CWE",
        "Bug_Inducing_Script_Misconfiguration_Label",
        "Bug_Inducing_Script_MisconfigurationFoundbyLLM",
        "Bug_Inducing_Script_CWE"
    ])

    row_count = 0

    for chunk in csv_reader:
        for index, row in chunk.iterrows():
            row_count += 1
            fixing_commit_code = str(row.get("Added_lines_fixing_commit", "")).strip()
            bug_inducing_commit_code = str(row.get("Added_lines_bug_inducing_commit", "")).strip()

            if not fixing_commit_code and not bug_inducing_commit_code:
                print(f"⏭️ Skipping Row {row_count} (Empty Scripts)")
                continue

            try:
                fixing_snippets = fixing_cwes = "Not analyzed"
                bug_snippets = bug_cwes = "Not analyzed"
                fixing_label = bug_label = "N/A"

                if fixing_commit_code:
                  with torch.inference_mode():
                    result_fixing = analyze_misconfiguration(fixing_commit_code)
                    torch.cuda.empty_cache()
                    issues_fixing = result_fixing.get("issues_found", [])
                    fixing_snippets = ", ".join(sorted(set(issue.get("misconfigured_snippet", "") for issue in issues_fixing))) if issues_fixing else "No issues detected"
                    fixing_cwes = ", ".join(sorted(set(issue.get("related_cwe", "") for issue in issues_fixing))) if issues_fixing else "None"
                    fixing_label = result_fixing.get("misconfiguration_label", "N/A")

                if bug_inducing_commit_code:
                  with torch.inference_mode():
                    result_bug = analyze_misconfiguration(bug_inducing_commit_code)
                    issues_bug = result_bug.get("issues_found", [])
                    bug_snippets = ", ".join(sorted(set(issue.get("misconfigured_snippet", "") for issue in issues_bug))) if issues_bug else "No issues detected"
                    bug_cwes = ", ".join(sorted(set(issue.get("related_cwe", "") for issue in issues_bug))) if issues_bug else "None"
                    bug_label = result_bug.get("misconfiguration_label", "N/A")

                writer.writerow([
                    fixing_commit_code,
                    bug_inducing_commit_code,
                    fixing_label,
                    fixing_snippets,
                    fixing_cwes,
                    bug_label,
                    bug_snippets,
                    bug_cwes
                ])


                print(f"✅ Row {row_count} processed")
                if fixing_commit_code:
                    print(json.dumps(result_fixing, indent=4))
                sys.stdout.flush()

            except Exception as e:
                print(f"❌ Error at Row {row_count}: {e}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Loading model...
# config.json:   0%|          | 0.00/893 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/41.6k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.89G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.51G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/7.88k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/777k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/442k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.06M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/958 [00:00<?, ?B/s]
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# /usr/local/lib/python3.11/dist-packages/bitsandbytes/nn/modules.py:451: UserWarning: Input type into Linear4bit is torch.float16, but bnb_4bit_compute_dtype=torch.float32 (default). This will lead to slow inference or training speed.
#   warnings.warn(
# Streaming output truncated to the last 5000 lines.
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-125"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 173 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "name: \\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 174 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "name: \\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 175 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "name: \\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 176 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "update_cache: yes",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "update_cache: yes",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "update_cache: yes",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "update_cache: yes",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "update_cache: yes",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "update_cache: yes",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "update_cache: yes",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "update_cache: yes",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "update_cache: yes",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "update_cache: yes",
#             "related_cwe": "CWE-125"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 177 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "monasca_orgs_body: name: '{{ monasca_grafana_control_plane_org }}' body: \\",
#             "related_cwe": "CWE-134"
#         },
#         {
#             "misconfigured_snippet": "monasca_user_body: loginOrEmail: '{{ monasca_grafana_admin_username }}' role: Admin body: \\\\",
#             "related_cwe": "CWE-134"
#         },
#         {
#             "misconfigured_snippet": "monasca_user_body: loginOrEmail: '{{ monasca_grafana_admin_username }}' role: Admin body: \\\\\\\\",
#             "related_cwe": "CWE-134"
#         },
#         {
#             "misconfigured_snippet": "monasca_user_body: loginOrEmail: '{{ monasca_grafana_admin_username }}' role: Admin body: \\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-134"
#         },
#         {
#             "misconfigured_snippet": "monasca_user_body: loginOrEmail: '{{ monasca_grafana_admin_username }}' role: Admin body: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-134"
#         },
#         {
#             "misconfigured_snippet": "monasca_user_body: loginOrEmail: '{{ monasca_grafana_admin_username }}' role: Admin body: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-134"
#         },
#         {
#             "misconfigured_snippet": "monasca_user_body: loginOrEmail: '{{ monasca_grafana_admin_username }}' role: Admin body: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-134"
#         },
#         {
#             "misconfigured_snippet": "monasca_user_body: loginOrEmail: '{{ monasca_grafana_admin_username }}' role: Admin body: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-134"
#         },
#         {
#             "misconfigured_snippet": "monasca_user_body: loginOrEmail: '{{ monasca_grafana_admin_username }}' role: Admin body: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-134"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 178 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "dest: \\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "dest: \\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "dest: \\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "dest: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "dest: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "dest: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "dest: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "dest: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "dest: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 179 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "dest: \\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "dest: \\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "dest: \\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "dest: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "dest: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "dest: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "dest: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "dest: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "dest: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 180 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "dest: \\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "dest: \\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "dest: \\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "dest: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "dest: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "dest: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "dest: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
# ...
#             "related_cwe": "CWE-122"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 279 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "cache_valid_time: 3600",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "update_cache: true",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "pkg: fail2ban",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "state: latest",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "state: started",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "enabled: yes",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "name: fail2ban",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "name: fail2ban",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "name: fail2ban",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "name: fail2ban",
#             "related_cwe": "CWE-22"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 280 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "ansible {{ inventory_hostname }} -m ping{{ (inventory_file == None) | ternary('','-i'+ inventory_file | string) }} -u root",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "ansible {{ inventory_hostname }} -m ping{{ (inventory_file == None) | ternary('','-i'+ inventory_file | string) }} -u root",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "ansible {{ inventory_hostname }} -m ping{{ (inventory_file == None) | ternary('','-i'+ inventory_file | string) }} -u root",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "ansible {{ inventory_hostname }} -m ping{{ (inventory_file == None) | ternary('','-i'+ inventory_file | string) }} -u root",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "ansible {{ inventory_hostname }} -m ping{{ (inventory_file == None) | ternary('','-i'+ inventory_file | string) }} -u root",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "ansible {{ inventory_hostname }} -m ping{{ (inventory_file == None) | ternary('','-i'+ inventory_file | string) }} -u root",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "ansible {{ inventory_hostname }} -m ping{{ (inventory_file == None) | ternary('','-i'+ inventory_file | string) }} -u root",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "ansible {{ inventory_hostname }} -m ping{{ (inventory_file == None) | ternary('','-i'+ inventory_file | string) }} -u root",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "ansible {{ inventory_hostname }} -m ping{{ (inventory_file == None) | ternary('','-i'+ inventory_file | string) }} -u root",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "ansible {{ inventory_hostname }} -m ping{{ (inventory_file == None) | ternary('','-i'+ inventory_file | string) }} -u root",
#             "related_cwe": "CWE-125"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 281 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "project_subtree: \\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "project_subtree: \\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "project_subtree: \\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "project_subtree: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "project_subtree: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "project_subtree: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "project_subtree: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "project_subtree: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         },
#         {
#             "misconfigured_snippet": "project_subtree: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-122"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 282 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "when: sensu_redis_server",
#             "related_cwe": "CWE-120"
#         },
#         {
#             "misconfigured_snippet": "when: sensu_rabbitmq_server",
#             "related_cwe": "CWE-120"
#         },
#         {
#             "misconfigured_snippet": "when: sensu_redis_server",
#             "related_cwe": "CWE-120"
#         },
#         {
#             "misconfigured_snippet": "when: sensu_rabbitmq_server",
#             "related_cwe": "CWE-120"
#         },
#         {
#             "misconfigured_snippet": "when: sensu_redis_server",
#             "related_cwe": "CWE-120"
#         },
#         {
#             "misconfigured_snippet": "when: sensu_rabbitmq_server",
#             "related_cwe": "CWE-120"
#         },
#         {
#             "misconfigured_snippet": "when: sensu_redis_server",
#             "related_cwe": "CWE-120"
#         },
#         {
#             "misconfigured_snippet": "when: sensu_rabbitmq_server",
#             "related_cwe": "CWE-120"
#         },
#         {
#             "misconfigured_snippet": "when: sensu_redis_server",
#             "related_cwe": "CWE-120"
#         },
#         {
#             "misconfigured_snippet": "when: sensu_rabbitmq_server",
#             "related_cwe": "CWE-120"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 283 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "enabled: yes",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "enabled: yes",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "enabled: yes",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "enabled: yes",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "enabled: yes",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "enabled: yes",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "enabled: yes",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "enabled: yes",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "enabled: yes",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "enabled: yes",
#             "related_cwe": "CWE-125"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 284 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "istio_git_repo: https://github.com/istio/istio.git",
#             "related_cwe": "CWE-20"
#         },
#         {
#             "misconfigured_snippet": "istio_git_repo: https://github.com/istio/istio.git",
#             "related_cwe": "CWE-20"
#         },
#         {
#             "misconfigured_snippet": "istio_git_repo: https://github.com/istio/istio.git",
#             "related_cwe": "CWE-20"
#         },
#         {
#             "misconfigured_snippet": "istio_git_repo: https://github.com/istio/istio.git",
#             "related_cwe": "CWE-20"
#         },
#         {
#             "misconfigured_snippet": "istio_git_repo: https://github.com/istio/istio.git",
#             "related_cwe": "CWE-20"
#         },
#         {
#             "misconfigured_snippet": "istio_git_repo: https://github.com/istio/istio.git",
#             "related_cwe": "CWE-20"
#         },
#         {
#             "misconfigured_snippet": "istio_git_repo: https://github.com/istio/istio.git",
#             "related_cwe": "CWE-20"
#         },
#         {
#             "misconfigured_snippet": "istio_git_repo: https://github.com/istio/istio.git",
#             "related_cwe": "CWE-20"
#         },
#         {
#             "misconfigured_snippet": "istio_git_repo: https://github.com/istio/istio.git",
#             "related_cwe": "CWE-20"
#         },
#         {
#             "misconfigured_snippet": "istio_git_repo: https://github.com/istio/istio.git",
#             "related_cwe": "CWE-20"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 285 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "value: sb-2.1.x",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "value: sb-2.1.x",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "value: sb-2.1.x",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "value: sb-2.1.x",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "value: sb-2.1.x",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "value: sb-2.1.x",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "value: sb-2.1.x",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "value: sb-2.1.x",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "value: sb-2.1.x",
#             "related_cwe": "CWE-125"
#         },
#         {
#             "misconfigured_snippet": "value: sb-2.1.x",
#             "related_cwe": "CWE-125"
#         }
#     ],
#     "misconfiguration_label": "1"
# }

# %%
# Required packages
import pandas as pd
from sklearn.metrics import precision_recall_fscore_support

# Load the dataset from Google Drive (update the path as needed)
df = pd.read_csv('/content/drive/My Drive/expermintstarcoder/ansible_final/final-ansible_dataset_after_varification_starcoder.csv')


# Convert the labels to numeric, coercing invalid entries to NaN
df['Fixing_Script_Misconfiguration_Label'] = pd.to_numeric(df['Fixing_Script_Misconfiguration_Label'], errors='coerce')
df['Bug_Inducing_Script_Misconfiguration_Label'] = pd.to_numeric(df['Bug_Inducing_Script_Misconfiguration_Label'], errors='coerce')

# Drop rows with NaN values in these columns
df.dropna(subset=['Fixing_Script_Misconfiguration_Label', 'Bug_Inducing_Script_Misconfiguration_Label'], inplace=True)

# Predicted labels for Fixing Script Misconfigurations
fixing_predicted_labels = df['verification_Fixing_Script'].astype(int)

# Predicted labels for Bug-Inducing Script Misconfigurations
bug_inducing_predicted_labels = df['verification_Bug_Inducing'].astype(int)

# Actual labels for Fixing Script Misconfigurations
true_fixing_labels = df['Fixing_Script_Misconfiguration_Label'].astype(int)

# Actual labels for Bug-Inducing Script Misconfigurations
true_bug_inducing_labels = df['Bug_Inducing_Script_Misconfiguration_Label'].astype(int)

# Calculate Precision, Recall, and F1-Score for Fixing Script Misconfigurations
fixing_precision, fixing_recall, fixing_f1, _ = precision_recall_fscore_support(
    true_fixing_labels,  # True labels for fixing misconfigurations
    fixing_predicted_labels,
    average='binary',
    zero_division=0  # Handle division by zero if no true positives or false negatives
)

# Calculate Precision, Recall, and F1-Score for Bug-Inducing Script Misconfigurations
# Here, we set pos_label=0 to treat 0 as the positive class
bug_inducing_precision, bug_inducing_recall, bug_inducing_f1, _ = precision_recall_fscore_support(
    true_bug_inducing_labels,  # True labels for bug-inducing misconfigurations
    bug_inducing_predicted_labels,
    average='binary',
    zero_division=0,  # Handle division by zero if no true positives or false negatives
    pos_label=1  # Treat 0 as the positive class for Bug-Inducing
)

# Overall F1-score (average of both fixing and bug-inducing F1 scores)
overall_f1 = (fixing_f1 + bug_inducing_f1) / 2

# Overall Recall (average of both fixing and bug-inducing recall scores)
overall_recall = (fixing_recall + bug_inducing_recall) / 2

# Accuracy for Fixing Script Misconfigurations
fixing_accuracy = (fixing_predicted_labels == true_fixing_labels).sum() / len(df)

# Accuracy for Bug-Inducing Script Misconfigurations
bug_inducing_accuracy = (bug_inducing_predicted_labels == true_bug_inducing_labels).sum() / len(df)

# Print out the metrics for Fixing Script Misconfigurations
print(f"Precision for Fixing Script Misconfigurations: {fixing_precision:.4f}")
print(f"Recall for Fixing Script Misconfigurations: {fixing_recall:.4f}")
print(f"F1-Score for Fixing Script Misconfigurations: {fixing_f1:.4f}")
print(f"Accuracy for Fixing Script Misconfigurations: {fixing_accuracy:.4f}")

# Print out the metrics for Bug-Inducing Script Misconfigurations
print(f"Precision for Bug-Inducing Script Misconfigurations: {bug_inducing_precision:.4f}")
print(f"Recall for Bug-Inducing Script Misconfigurations: {bug_inducing_recall:.4f}")
print(f"F1-Score for Bug-Inducing Script Misconfigurations: {bug_inducing_f1:.4f}")
print(f"Accuracy for Bug-Inducing Script Misconfigurations: {bug_inducing_accuracy:.4f}")

# Print Overall Metrics
print(f"Overall F1-Score: {overall_f1:.4f}")
print(f"Overall Recall: {overall_recall:.4f}")
# Out:
# Precision for Fixing Script Misconfigurations: 0.9940
# Recall for Fixing Script Misconfigurations: 0.6255
# F1-Score for Fixing Script Misconfigurations: 0.7678
# Accuracy for Fixing Script Misconfigurations: 0.6231
# Precision for Bug-Inducing Script Misconfigurations: 1.0000
# Recall for Bug-Inducing Script Misconfigurations: 0.4515
# F1-Score for Bug-Inducing Script Misconfigurations: 0.6221
# Accuracy for Bug-Inducing Script Misconfigurations: 0.4515
# Overall F1-Score: 0.6950
# Overall Recall: 0.5385

# %%
# Required packages
import pandas as pd
from sklearn.metrics import precision_recall_fscore_support

# Load the dataset (update path as needed)
df = pd.read_csv('/content/drive/My Drive/expermintstarcoder/ansible_final/final-ansible_dataset_after_varification_starcoder.csv')

# Convert the labels to numeric (in case of non-numeric entries)
df['Fixing_Script_Misconfiguration_Label'] = pd.to_numeric(df['Fixing_Script_Misconfiguration_Label'], errors='coerce')
df['Bug_Inducing_Script_Misconfiguration_Label'] = pd.to_numeric(df['Bug_Inducing_Script_Misconfiguration_Label'], errors='coerce')

# Drop rows with NaN values in these columns
df.dropna(subset=['Fixing_Script_Misconfiguration_Label', 'Bug_Inducing_Script_Misconfiguration_Label'], inplace=True)

# Predicted labels for Fixing Script Misconfigurations (verification labels)
fixing_verification_labels = df['verification_Fixing_Script']

# Predicted labels for Bug-Inducing Script Misconfigurations (verification labels)
bug_inducing_verification_labels = df['verification_Bug_Inducing']

# Actual labels for Bug-Inducing Script Misconfigurations (truth labels)
true_bug_inducing_labels = df['Bug_Inducing_Script_Misconfiguration_Label']

# Calculate Accuracy for Bug-Inducing Script Misconfigurations (mean of verification labels)
bug_inducing_accuracy = bug_inducing_verification_labels.mean()

# Precision, Recall, and F1-Score for Bug-Inducing Script Misconfigurations
bug_inducing_precision, bug_inducing_recall, bug_inducing_f1, _ = precision_recall_fscore_support(
    [1] * len(bug_inducing_verification_labels),  # Truth label is always 1
    bug_inducing_verification_labels,
    average='binary',
    zero_division=0,  # Handle division by zero if no true positives or false negatives
    pos_label=1  # Treat 1 as the positive class for Bug-Inducing (CWE-related)
)

# Print out the metrics for Bug-Inducing Script Misconfigurations
print(f"Precision for Bug-Inducing Script Misconfigurations: {bug_inducing_precision:.4f}")
print(f"Recall for Bug-Inducing Script Misconfigurations: {bug_inducing_recall:.4f}")
print(f"F1-Score for Bug-Inducing Script Misconfigurations: {bug_inducing_f1:.4f}")
print(f"Accuracy for Bug-Inducing Script Misconfigurations: {bug_inducing_accuracy:.4f}")

# Similarly, calculate metrics for Fixing Script Misconfigurations:

# Predicted labels for Fixing Script Misconfigurations (verification labels)
fixing_verification_labels = df['verification_Fixing_Script']

# Accuracy for Fixing Script Misconfigurations (mean of verification labels)
fixing_accuracy = fixing_verification_labels.mean()

# Precision, Recall, and F1-Score for Fixing Script Misconfigurations
fixing_precision, fixing_recall, fixing_f1, _ = precision_recall_fscore_support(
    [1] * len(fixing_verification_labels),  # Truth label is always 1
    fixing_verification_labels,
    average='binary',
    zero_division=0,  # Handle division by zero if no true positives or false negatives
    pos_label=1  # Treat 1 as the positive class for Fixing (CWE-related)
)

# Print out the metrics for Fixing Script Misconfigurations
print(f"Precision for Fixing Script Misconfigurations: {fixing_precision:.4f}")
print(f"Recall for Fixing Script Misconfigurations: {fixing_recall:.4f}")
print(f"F1-Score for Fixing Script Misconfigurations: {fixing_f1:.4f}")
print(f"Accuracy for Fixing Script Misconfigurations: {fixing_accuracy:.4f}")

# Calculate Overall Metrics (averaging between Fixing and Bug-Inducing)
overall_precision = (fixing_precision + bug_inducing_precision) / 2
overall_recall = (fixing_recall + bug_inducing_recall) / 2
overall_f1 = (fixing_f1 + bug_inducing_f1) / 2
overall_accuracy = (fixing_accuracy + bug_inducing_accuracy) / 2

# Print out the overall metrics
print(f"Overall Precision: {overall_precision:.4f}")
print(f"Overall Recall: {overall_recall:.4f}")
print(f"Overall F1-Score: {overall_f1:.4f}")
print(f"Overall Accuracy: {overall_accuracy:.4f}")
# Out:
# Precision for Bug-Inducing Script Misconfigurations: 1.0000
# Recall for Bug-Inducing Script Misconfigurations: 0.4515
# F1-Score for Bug-Inducing Script Misconfigurations: 0.6221
# Accuracy for Bug-Inducing Script Misconfigurations: 0.4515
# Precision for Fixing Script Misconfigurations: 1.0000
# Recall for Fixing Script Misconfigurations: 0.6269
# F1-Score for Fixing Script Misconfigurations: 0.7706
# Accuracy for Fixing Script Misconfigurations: 0.6269
# Overall Precision: 1.0000
# Overall Recall: 0.5392
# Overall F1-Score: 0.6964
# Overall Accuracy: 0.5392

# %%
import pandas as pd
from sklearn.metrics import (
    accuracy_score,
    precision_recall_fscore_support,
    precision_recall_curve,
    auc,
    matthews_corrcoef
)

# Load the dataset
df = pd.read_csv('/content/drive/My Drive/expermintstarcoder/ansible_final/final-ansible_dataset_after_varification_starcoder.csv')

# Convert to numeric
df['Fixing_Script_Misconfiguration_Label'] = pd.to_numeric(df['Fixing_Script_Misconfiguration_Label'], errors='coerce')
df['Bug_Inducing_Script_Misconfiguration_Label'] = pd.to_numeric(df['Bug_Inducing_Script_Misconfiguration_Label'], errors='coerce')
df['verification_Fixing_Script'] = pd.to_numeric(df['verification_Fixing_Script'], errors='coerce')
df['verification_Bug_Inducing'] = pd.to_numeric(df['verification_Bug_Inducing'], errors='coerce')

# Drop missing values
df.dropna(subset=[
    'Fixing_Script_Misconfiguration_Label',
    'Bug_Inducing_Script_Misconfiguration_Label',
    'verification_Fixing_Script',
    'verification_Bug_Inducing'
], inplace=True)

# Fixing labels
true_fixing = df['Fixing_Script_Misconfiguration_Label'].astype(int)
pred_fixing = df['verification_Fixing_Script'].astype(int)

# Inducing labels
true_inducing = df['Bug_Inducing_Script_Misconfiguration_Label'].astype(int)
pred_inducing = df['verification_Bug_Inducing'].astype(int)

# Metrics for Fixing
fixing_accuracy = accuracy_score(true_fixing, pred_fixing)
fixing_precision, fixing_recall, fixing_f1, _ = precision_recall_fscore_support(true_fixing, pred_fixing, average='binary', pos_label=1, zero_division=0)
fixing_mcc = matthews_corrcoef(true_fixing, pred_fixing)
fixing_prec_curve, fixing_rec_curve, _ = precision_recall_curve(true_fixing, pred_fixing)
fixing_pr_auc = auc(fixing_rec_curve, fixing_prec_curve)

# Metrics for Inducing
inducing_accuracy = accuracy_score(true_inducing, pred_inducing)
inducing_precision, inducing_recall, inducing_f1, _ = precision_recall_fscore_support(true_inducing, pred_inducing, average='binary', pos_label=1, zero_division=0)
inducing_mcc = matthews_corrcoef(true_inducing, pred_inducing)
inducing_prec_curve, inducing_rec_curve, _ = precision_recall_curve(true_inducing, pred_inducing)
inducing_pr_auc = auc(inducing_rec_curve, inducing_prec_curve)

# Overall metrics (average of both)
overall_accuracy = (fixing_accuracy + inducing_accuracy) / 2
overall_precision = (fixing_precision + inducing_precision) / 2
overall_recall = (fixing_recall + inducing_recall) / 2
overall_f1 = (fixing_f1 + inducing_f1) / 2
overall_pr_auc = (fixing_pr_auc + inducing_pr_auc) / 2
overall_mcc = (fixing_mcc + inducing_mcc) / 2

# Print Fixing Metrics
print(f"Fixing → Precision: {fixing_precision:.4f}, Recall: {fixing_recall:.4f}, F1: {fixing_f1:.4f}, Accuracy: {fixing_accuracy:.4f}, PR-AUC: {fixing_pr_auc:.4f}, MCC: {fixing_mcc:.4f}")

# Print Inducing Metrics
print(f"Inducing → Precision: {inducing_precision:.4f}, Recall: {inducing_recall:.4f}, F1: {inducing_f1:.4f}, Accuracy: {inducing_accuracy:.4f}, PR-AUC: {inducing_pr_auc:.4f}, MCC: {inducing_mcc:.4f}")

# Print Overall Metrics
print(f"Overall → Precision: {overall_precision:.4f}, Recall: {overall_recall:.4f}, F1: {overall_f1:.4f}, Accuracy: {overall_accuracy:.4f}, PR-AUC: {overall_pr_auc:.4f}, MCC: {overall_mcc:.4f}")
# Out:
# Fixing → Precision: 0.9940, Recall: 0.6255, F1: 0.7678, Accuracy: 0.6231, PR-AUC: 0.9963, MCC: -0.0472
# Inducing → Precision: 1.0000, Recall: 0.4515, F1: 0.6221, Accuracy: 0.4515, PR-AUC: 1.0000, MCC: 0.0000
# Overall → Precision: 0.9970, Recall: 0.5385, F1: 0.6950, Accuracy: 0.5373, PR-AUC: 0.9982, MCC: -0.0236
