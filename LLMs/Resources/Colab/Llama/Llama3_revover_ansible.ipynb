# %%
# !pip install jsonformer
# Out:
# Collecting jsonformer
#   Downloading jsonformer-0.12.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting termcolor<3.0.0,>=2.3.0 (from jsonformer)
#   Downloading termcolor-2.5.0-py3-none-any.whl.metadata (6.1 kB)
# Downloading jsonformer-0.12.0-py3-none-any.whl (6.6 kB)
# Downloading termcolor-2.5.0-py3-none-any.whl (7.8 kB)
# Installing collected packages: termcolor, jsonformer
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 3.1.0
#     Uninstalling termcolor-3.1.0:
#       Successfully uninstalled termcolor-3.1.0
# Successfully installed jsonformer-0.12.0 termcolor-2.5.0

# %%
from google.colab import drive
import pandas as pd
drive.mount('/content/drive')

# Now provide the full path to your file in Google Drive
csv_file = "/content/drive/My Drive/expermintstarcoder/PuppetScripts_V2.csv"
csv_file_ansible = "/content/drive/My Drive/expermintstarcoder/merged_file_ansible_defect.csv"
df = pd.read_csv(csv_file)
# Out:
# Mounted at /content/drive

# %%
from huggingface_hub import login
login(token="")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#using meta-llama 3

# %%
# !pip show transformers
# Out:
# Name: transformers
# Version: 4.51.1
# Summary: State-of-the-art Machine Learning for JAX, PyTorch and TensorFlow
# Home-page: https://github.com/huggingface/transformers
# Author: The Hugging Face team (past and future) with the help of all our contributors (https://github.com/huggingface/transformers/graphs/contributors)
# Author-email: transformers@huggingface.co
# License: Apache 2.0 License
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: filelock, huggingface-hub, numpy, packaging, pyyaml, regex, requests, safetensors, tokenizers, tqdm
# Required-by: peft, sentence-transformers

# %%
# !pip uninstall transformers
# Out:
# Found existing installation: transformers 4.49.0
# Uninstalling transformers-4.49.0:
#   Would remove:
#     /usr/local/bin/transformers-cli
#     /usr/local/lib/python3.11/dist-packages/transformers-4.49.0.dist-info/*
#     /usr/local/lib/python3.11/dist-packages/transformers/*
# Proceed (Y/n)? y
#   Successfully uninstalled transformers-4.49.0

# %%
import torch
torch.cuda.empty_cache()

# %%
import torch
print("PyTorch version:", torch.__version__)
import transformers
print("Transformers version:", transformers.__version__)
# Out:
# PyTorch version: 2.5.1+cu124
# Transformers version: 4.48.3

# %%
# !pip install transformers==4.48.3
# Out:
# Collecting transformers==4.48.3
#   Downloading transformers-4.48.3-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (0.31.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers==4.48.3) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers==4.48.3) (4.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers==4.48.3) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.48.3) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.48.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.48.3) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.48.3) (2025.4.26)
# Downloading transformers-4.48.3-py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 83.3 MB/s eta 0:00:00
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.51.3
#     Uninstalling transformers-4.51.3:
#       Successfully uninstalled transformers-4.51.3
# Successfully installed transformers-4.48.3

# %%
# !pip install torch==2.5.1 torchvision==0.20.1
# Out:
# Collecting torch==2.5.1
#   Downloading torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting torchvision==0.20.1
#   Downloading torchvision-0.20.1-cp311-cp311-manylinux1_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch==2.5.1)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch==2.5.1)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch==2.5.1)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch==2.5.1)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch==2.5.1)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch==2.5.1)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch==2.5.1)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch==2.5.1)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch==2.5.1)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch==2.5.1)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.1.0 (from torch==2.5.1)
#   Downloading triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (1.13.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision==0.20.1) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision==0.20.1) (11.2.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch==2.5.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.5.1) (3.0.2)
# Downloading torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl (906.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━ 537.7/906.5 MB 194.8 MB/s eta 0:00:02^C

# %%
pip install coqui-tts
# Out:
# Collecting coqui-tts
#   Downloading coqui_tts-0.26.0-py3-none-any.whl.metadata (19 kB)
# Collecting anyascii>=0.3.0 (from coqui-tts)
#   Downloading anyascii-0.3.2-py3-none-any.whl.metadata (1.5 kB)
# Collecting coqpit-config<0.3.0,>=0.2.0 (from coqui-tts)
#   Downloading coqpit_config-0.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting coqui-tts-trainer<0.3.0,>=0.2.0 (from coqui-tts)
#   Downloading coqui_tts_trainer-0.2.3-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: cython>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from coqui-tts) (3.0.12)
# Requirement already satisfied: einops>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from coqui-tts) (0.8.1)
# Collecting encodec>=0.1.1 (from coqui-tts)
#   Downloading encodec-0.1.1.tar.gz (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 83.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: fsspec>=2023.6.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2023.6.0->coqui-tts) (2025.3.2)
# Collecting gruut>=2.4.0 (from gruut[de,es,fr]>=2.4.0->coqui-tts)
#   Downloading gruut-2.4.0.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 kB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: inflect>=5.6.0 in /usr/local/lib/python3.11/dist-packages (from coqui-tts) (7.5.0)
# Requirement already satisfied: librosa>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from coqui-tts) (0.11.0)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from coqui-tts) (3.10.0)
# Collecting monotonic-alignment-search>=0.1.0 (from coqui-tts)
#   Downloading monotonic_alignment_search-0.1.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting num2words>=0.5.14 (from coqui-tts)
#   Downloading num2words-0.5.14-py3-none-any.whl.metadata (13 kB)
# Collecting numpy<2.0,>=1.25.2 (from coqui-tts)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=23.1 in /usr/local/lib/python3.11/dist-packages (from coqui-tts) (24.2)
# Collecting pysbd>=0.3.4 (from coqui-tts)
#   Downloading pysbd-0.3.4-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.11/dist-packages (from coqui-tts) (6.0.2)
# Requirement already satisfied: scipy>=1.11.2 in /usr/local/lib/python3.11/dist-packages (from coqui-tts) (1.15.3)
# Requirement already satisfied: soundfile>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from coqui-tts) (0.13.1)
# Collecting spacy<3.8,>=3.2 (from spacy[ja]<3.8,>=3.2->coqui-tts)
#   Downloading spacy-3.7.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (27 kB)
# Requirement already satisfied: torch>=2.1 in /usr/local/lib/python3.11/dist-packages (from coqui-tts) (2.6.0+cu124)
# Requirement already satisfied: torchaudio>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from coqui-tts) (2.6.0+cu124)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.11/dist-packages (from coqui-tts) (4.67.1)
# Requirement already satisfied: transformers>=4.47.0 in /usr/local/lib/python3.11/dist-packages (from coqui-tts) (4.48.3)
# Requirement already satisfied: typing-extensions>=4.10 in /usr/local/lib/python3.11/dist-packages (from coqui-tts) (4.13.2)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.11/dist-packages (from coqui-tts-trainer<0.3.0,>=0.2.0->coqui-tts) (5.9.5)
# Requirement already satisfied: tensorboard>=2.17.0 in /usr/local/lib/python3.11/dist-packages (from coqui-tts-trainer<0.3.0,>=0.2.0->coqui-tts) (2.18.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2023.6.0->coqui-tts) (3.11.15)
# Requirement already satisfied: Babel<3.0.0,>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts) (2.17.0)
# Collecting dateparser~=1.1.1 (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts)
#   Downloading dateparser-1.1.8-py2.py3-none-any.whl.metadata (27 kB)
# Collecting gruut-ipa<1.0,>=0.12.0 (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts)
#   Downloading gruut-ipa-0.13.0.tar.gz (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 9.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gruut_lang_en~=2.0.0 (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts)
#   Downloading gruut_lang_en-2.0.1.tar.gz (15.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 113.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting jsonlines~=1.2.0 (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts)
#   Downloading jsonlines-1.2.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: networkx>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts) (3.4.2)
# Collecting python-crfsuite~=0.9.7 (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts)
#   Downloading python_crfsuite-0.9.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Collecting gruut_lang_de~=2.0.0 (from gruut[de,es,fr]>=2.4.0->coqui-tts)
#   Downloading gruut_lang_de-2.0.1.tar.gz (18.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 108.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gruut_lang_es~=2.0.0 (from gruut[de,es,fr]>=2.4.0->coqui-tts)
#   Downloading gruut_lang_es-2.0.1.tar.gz (31.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 73.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gruut_lang_fr~=2.0.0 (from gruut[de,es,fr]>=2.4.0->coqui-tts)
#   Downloading gruut_lang_fr-2.0.2.tar.gz (10.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 88.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: more_itertools>=8.5.0 in /usr/local/lib/python3.11/dist-packages (from inflect>=5.6.0->coqui-tts) (10.7.0)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from inflect>=5.6.0->coqui-tts) (4.4.2)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.1->coqui-tts) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.1->coqui-tts) (0.60.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.1->coqui-tts) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.1->coqui-tts) (1.5.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.1->coqui-tts) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.1->coqui-tts) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.1->coqui-tts) (0.5.0.post1)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.1->coqui-tts) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.1->coqui-tts) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->coqui-tts) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->coqui-tts) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->coqui-tts) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->coqui-tts) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->coqui-tts) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->coqui-tts) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->coqui-tts) (2.9.0.post0)
# Collecting docopt>=0.6.2 (from num2words>=0.5.14->coqui-tts)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.12.0->coqui-tts) (1.17.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (3.0.9)
# Collecting thinc<8.3.0,>=8.2.2 (from spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts)
#   Downloading thinc-8.2.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (0.15.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (2.11.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (75.2.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (3.5.0)
# Collecting sudachipy!=0.6.1,>=0.5.2 (from spacy[ja]<3.8,>=3.2->coqui-tts)
#   Downloading SudachiPy-0.6.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting sudachidict-core>=20211220 (from spacy[ja]<3.8,>=3.2->coqui-tts)
#   Downloading SudachiDict_core-20250129-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->coqui-tts) (3.18.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.1->coqui-tts)
#   Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.1->coqui-tts)
#   Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.1->coqui-tts)
#   Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.1->coqui-tts)
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.1->coqui-tts)
#   Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.1->coqui-tts)
#   Using cached nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.1->coqui-tts)
#   Using cached nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.1->coqui-tts)
#   Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.1->coqui-tts)
#   Using cached nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->coqui-tts) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->coqui-tts) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->coqui-tts) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.1->coqui-tts)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->coqui-tts) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->coqui-tts) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.1->coqui-tts) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.47.0->coqui-tts) (0.31.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.47.0->coqui-tts) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.47.0->coqui-tts) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.47.0->coqui-tts) (0.5.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts) (1.20.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.12.0->coqui-tts) (2.22)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from dateparser~=1.1.1->gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts) (2025.2)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.11/dist-packages (from dateparser~=1.1.1->gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts) (5.3.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers>=4.47.0->coqui-tts) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from jsonlines~=1.2.0->gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts) (1.17.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (1.3.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa>=0.10.1->coqui-tts) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa>=0.10.1->coqui-tts) (4.3.8)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (2025.4.26)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.0->librosa>=0.10.1->coqui-tts) (3.6.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.3.0,>=0.2.0->coqui-tts) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.3.0,>=0.2.0->coqui-tts) (1.71.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.3.0,>=0.2.0->coqui-tts) (3.8)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.3.0,>=0.2.0->coqui-tts) (5.29.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.3.0,>=0.2.0->coqui-tts) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.3.0,>=0.2.0->coqui-tts) (3.1.3)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.3.0,>=8.2.2->spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts)
#   Downloading blis-0.7.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.4 kB)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (2.19.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8,>=3.2->spacy[ja]<3.8,>=3.2->coqui-tts) (0.1.2)
# Downloading coqui_tts-0.26.0-py3-none-any.whl (861 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 861.8/861.8 kB 54.1 MB/s eta 0:00:00
# Downloading anyascii-0.3.2-py3-none-any.whl (289 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 26.9 MB/s eta 0:00:00
# Downloading coqpit_config-0.2.0-py3-none-any.whl (15 kB)
# Downloading coqui_tts_trainer-0.2.3-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 kB 5.8 MB/s eta 0:00:00
# Downloading monotonic_alignment_search-0.1.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (612 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.8/612.8 kB 45.7 MB/s eta 0:00:00
# Downloading num2words-0.5.14-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 13.7 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 120.2 MB/s eta 0:00:00
# Downloading pysbd-0.3.4-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 6.7 MB/s eta 0:00:00
# Downloading spacy-3.7.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 84.9 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 137.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 108.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 44.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 20.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 114.8 MB/s eta 0:00:00
# Downloading dateparser-1.1.8-py2.py3-none-any.whl (293 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.8/293.8 kB 24.7 MB/s eta 0:00:00
# Downloading jsonlines-1.2.0-py2.py3-none-any.whl (7.6 kB)
# Downloading python_crfsuite-0.9.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 69.2 MB/s eta 0:00:00
# Downloading SudachiDict_core-20250129-py3-none-any.whl (72.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.1/72.1 MB 34.7 MB/s eta 0:00:00
# Downloading SudachiPy-0.6.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 77.9 MB/s eta 0:00:00
# Downloading thinc-8.2.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (920 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 920.2/920.2 kB 56.2 MB/s eta 0:00:00
# Downloading blis-0.7.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 119.0 MB/s eta 0:00:00
# Building wheels for collected packages: encodec, gruut, docopt, gruut-ipa, gruut_lang_de, gruut_lang_en, gruut_lang_es, gruut_lang_fr
#   Building wheel for encodec (setup.py) ... done
#   Created wheel for encodec: filename=encodec-0.1.1-py3-none-any.whl size=45759 sha256=c519fd5d79f9d0962eb6ec7bcd29bc2784bcae854cb628748cf637b8e6efb965
#   Stored in directory: /root/.cache/pip/wheels/b4/a4/88/480018a664e58ca7ce6708759193ee51b017b3b72aa3df8a85
#   Building wheel for gruut (setup.py) ... done
#   Created wheel for gruut: filename=gruut-2.4.0-py3-none-any.whl size=86758 sha256=4310b9176ea02099a99de4f4e4c0c7d9397b306e5e27a8d4c74fc34232da282a
#   Stored in directory: /root/.cache/pip/wheels/7f/ff/c1/291e91d9b767694fb7f30f6cd16a5b89d6d67afacd796ad842
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=ff2bea203263e9e1a9ee21293eca964e3281f527f3d42b4ffa1f2f7df9fd2d1f
#   Stored in directory: /root/.cache/pip/wheels/1a/b0/8c/4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
#   Building wheel for gruut-ipa (setup.py) ... done
#   Created wheel for gruut-ipa: filename=gruut_ipa-0.13.0-py3-none-any.whl size=104873 sha256=d5bc8bbef822e15735b3a1f17313150e2c7709d4461b74d4200154cca78ff080
#   Stored in directory: /root/.cache/pip/wheels/c7/10/89/a5908dd7a9a032229684b7679396785e19f816667f788087fb
#   Building wheel for gruut_lang_de (setup.py) ... done
#   Created wheel for gruut_lang_de: filename=gruut_lang_de-2.0.1-py3-none-any.whl size=18498314 sha256=4f03c48bc9d7e3e58a97a9818c31451cb7152cf2e9018b97c9279a2a97a8c888
#   Stored in directory: /root/.cache/pip/wheels/87/fa/df/5fdf5d3cc26ba859b8698a1f28581d1a6aa081edc6df9847ab
#   Building wheel for gruut_lang_en (setup.py) ... done
#   Created wheel for gruut_lang_en: filename=gruut_lang_en-2.0.1-py3-none-any.whl size=15326858 sha256=2d025cb076c7ceeda65d52e1fbca948bde09b5920622efdb2341e0c0917a4f91
#   Stored in directory: /root/.cache/pip/wheels/06/30/52/dc5cd222b4bbde285838fed1f96636e96f85cd75493e79a978
#   Building wheel for gruut_lang_es (setup.py) ... done
#   Created wheel for gruut_lang_es: filename=gruut_lang_es-2.0.1-py3-none-any.whl size=32173927 sha256=60a9795e4130e12474688ac8ab6001de5f7d40623d337f486b751874e943f87a
#   Stored in directory: /root/.cache/pip/wheels/c8/eb/59/30b5d15e56347e595f613036cbea0f807ad9621c75cd75d912
#   Building wheel for gruut_lang_fr (setup.py) ... done
#   Created wheel for gruut_lang_fr: filename=gruut_lang_fr-2.0.2-py3-none-any.whl size=10968767 sha256=ebaf776c163d06a8dbc92dc1890120fcdb6013c5c83b4ee55cca3800264b3827
#   Stored in directory: /root/.cache/pip/wheels/e0/e7/a0/7c416a3eeaa94ca71bf7bcbc6289cced2263d8ba35e82444bb
# Successfully built encodec gruut docopt gruut-ipa gruut_lang_de gruut_lang_en gruut_lang_es gruut_lang_fr
# Installing collected packages: sudachipy, gruut_lang_fr, gruut_lang_es, gruut_lang_en, gruut_lang_de, docopt, sudachidict-core, python-crfsuite, pysbd, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, num2words, jsonlines, gruut-ipa, coqpit-config, anyascii, nvidia-cusparse-cu12, nvidia-cudnn-cu12, dateparser, blis, nvidia-cusolver-cu12, gruut, thinc, spacy, monotonic-alignment-search, coqui-tts-trainer, encodec, coqui-tts
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: blis
#     Found existing installation: blis 1.3.0
#     Uninstalling blis-1.3.0:
#       Successfully uninstalled blis-1.3.0
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.3.6
#     Uninstalling thinc-8.3.6:
#       Successfully uninstalled thinc-8.3.6
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.8.5
#     Uninstalling spacy-3.8.5:
#       Successfully uninstalled spacy-3.8.5
# Successfully installed anyascii-0.3.2 blis-0.7.11 coqpit-config-0.2.0 coqui-tts-0.26.0 coqui-tts-trainer-0.2.3 dateparser-1.1.8 docopt-0.6.2 encodec-0.1.1 gruut-2.4.0 gruut-ipa-0.13.0 gruut_lang_de-2.0.1 gruut_lang_en-2.0.1 gruut_lang_es-2.0.1 gruut_lang_fr-2.0.2 jsonlines-1.2.0 monotonic-alignment-search-0.1.1 num2words-0.5.14 numpy-1.26.4 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pysbd-0.3.4 python-crfsuite-0.9.11 spacy-3.7.5 sudachidict-core-20250129 sudachipy-0.6.10 thinc-8.2.5

# %%
# Install gdown
# !pip install gdown -q

# Replace <file_id> with your actual file ID
# !gdown --id <file_id>
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `newline'
# /bin/bash: -c: line 1: `gdown --id <file_id>'

# %%
import gdown



file_id = '1FBc0QCwF0Zv48qp6Wn2jQec03qxiUeLG'
url = f'https://drive.google.com/uc?id={file_id}'
output = 'ansible_datasat.csv'  # You can name it anything

gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1FBc0QCwF0Zv48qp6Wn2jQec03qxiUeLG
# To: /content/ansible_datasat.csv
# 100%|██████████| 449k/449k [00:00<00:00, 138MB/s]
# 'ansible_datasat.csv'

# %%
import pandas as pd

# Load CSV file
df = pd.read_csv('ansible_datasat.csv')

# Show first few rows
df.head(2)
# Out:
#                                   Commit_id  \
# 0  5ee1e89cebf89a85e1ccb4fdc4c55d4b0e5c8f4a
# 1  b6a5ef7c8339e29cefdefa0fa5e25ec2b9785df9
#
#                            Added_lines_fixing_commit  \
# 0    command: php occ config:system:set {{ item.n...
# 1    when: (not _nextcloud_conf.stat.exists) or (...
#
#                      Added_lines_bug_inducing_commit
# 0  - name: "[NC] - Set Nextcloud settings in conf...
# 1    check_mode: no\n  when: _nextcloud_configure...

# %%
import pandas as pd
import torch
import json
import csv
from transformers import AutoModelForCausalLM, AutoTokenizer,BitsAndBytesConfig
from jsonformer import Jsonformer
from google.colab import drive
import torch
import sys
import os
# ========== 1. Mount Google Drive ==========

# ========== 2. Paths ==========
drive.mount('/content/drive')

# ========== 3. File Paths ==========
drive_folder = '/content/drive/MyDrive/expermintstarcoder'
input_file = os.path.join(drive_folder, 'imp/merged_file_ansible.csv')

output_file = os.path.join(drive_folder, 'final-ansible_dataset_befor_varification.csv')



# ========== 4. Load Model & Tokenizer ==========
model_name = "meta-llama/Meta-Llama-3-8B"
device = "cuda" if torch.cuda.is_available() else "cpu"

# ========== 4. Load Model & Tokenizer ==========
print("Loading model...")
bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_use_double_quant=True,
        bnb_4bit_quant_type="nf4"
    )

model = AutoModelForCausalLM.from_pretrained(
        model_name,
        device_map="auto",
        quantization_config=bnb_config
    )
tokenizer = AutoTokenizer.from_pretrained(model_name)

tokenizer.add_eos_token = True
if '<pad>' not in tokenizer.get_vocab():
        tokenizer.add_special_tokens({"pad_token": "<pad>"})
model.resize_token_embeddings(len(tokenizer))
model.config.pad_token_id = tokenizer.pad_token_id

if tokenizer.eos_token is None:
   tokenizer.eos_token = "[EOS]"

model.eval()
# ========== 5. Define JSON Schema ==========
json_schema = {
    "type": "object",
    "properties": {
        "issues_found": {
            "type": "array",
            "items": {
                "type": "object",
                "properties": {
                    "misconfigured_snippet": {"type": "string"},
                    "related_cwe": {"type": "string"},
                }
            }
        },
        "misconfiguration_label": {"type": "string"}
    }
}

# ========== 6. Misconfiguration Analyzer ==========
def analyze_misconfiguration(code_snippet):
    prompt = f"""
    You are a security expert specializing in Ansible configuration security.
    Your task is to analyze the following Ansible playbook/task and identify only critical security misconfigurations that could lead to vulnerabilities and have a real CWE ID.
    Focus only on the available code and avoid making assumptions about unavailable details.

    Ansible Playbook to Analyze:
    ```yaml
    {code_snippet}
    ```

    Response Format:
    Return the response in **valid JSON format**:

    - If there are critical issues:
    ```json
    {{
      "issues_found": [
        {{
          "misconfigured_snippet": "<actual misconfigured code snippet>",
          "related_cwe": "<CWE-ID>"
        }}
      ],
      "misconfiguration_label": 1
    }}
    ```

    - If there are NO critical issues:
    ```json
    {{
      "issues_found": [],
      "misconfiguration_label": 0
    }}
    ```

    Instructions:
    - Only list real misconfigurations tied to known CWE IDs.
    - Do NOT insert "N/A".
    - Do not include syntax errors.
    - If no critical misconfiguration is found, return an empty issues_found array.
    """
    truncated_prompt = tokenizer.decode(
    tokenizer.encode(prompt, max_length=1000, truncation=True),

    )

    structured_output = Jsonformer(
        model=model,
        tokenizer=tokenizer,
        json_schema=json_schema,
        prompt=truncated_prompt,
        max_string_token_length=150,
    )

    return structured_output()


# ========== 7. Write CSV ==========
# Remove output file if it exists

chunksize = 5  # You can adjust this
csv_reader = pd.read_csv(input_file, chunksize=chunksize, skiprows=range(1, 214))

with open(output_file, mode='w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow([
        "Added_lines_fixing_commit",
        "Added_lines_bug_inducing_commit",
        "Fixing_Script_Misconfiguration_Label",
        "Fixing_Script_MisconfigurationFoundbyLLM",
        "Fixing_Script_CWE",
        "Bug_Inducing_Script_Misconfiguration_Label",
        "Bug_Inducing_Script_MisconfigurationFoundbyLLM",
        "Bug_Inducing_Script_CWE"
    ])

    row_count = 0

    for chunk in csv_reader:
        for index, row in chunk.iterrows():
            row_count += 1
            fixing_commit_code = str(row.get("Added_lines_fixing_commit", "")).strip()
            bug_inducing_commit_code = str(row.get("Added_lines_bug_inducing_commit", "")).strip()

            if not fixing_commit_code and not bug_inducing_commit_code:
                print(f"⏭️ Skipping Row {row_count} (Empty Scripts)")
                continue

            try:
                fixing_snippets = fixing_cwes = "Not analyzed"
                bug_snippets = bug_cwes = "Not analyzed"
                fixing_label = bug_label = "N/A"

                if fixing_commit_code:
                  with torch.inference_mode():
                    result_fixing = analyze_misconfiguration(fixing_commit_code)
                    torch.cuda.empty_cache()
                    issues_fixing = result_fixing.get("issues_found", [])
                    fixing_snippets = ", ".join(sorted(set(issue.get("misconfigured_snippet", "") for issue in issues_fixing))) if issues_fixing else "No issues detected"
                    fixing_cwes = ", ".join(sorted(set(issue.get("related_cwe", "") for issue in issues_fixing))) if issues_fixing else "None"
                    fixing_label = result_fixing.get("misconfiguration_label", "N/A")

                if bug_inducing_commit_code:
                  with torch.inference_mode():
                    result_bug = analyze_misconfiguration(bug_inducing_commit_code)
                    issues_bug = result_bug.get("issues_found", [])
                    bug_snippets = ", ".join(sorted(set(issue.get("misconfigured_snippet", "") for issue in issues_bug))) if issues_bug else "No issues detected"
                    bug_cwes = ", ".join(sorted(set(issue.get("related_cwe", "") for issue in issues_bug))) if issues_bug else "None"
                    bug_label = result_bug.get("misconfiguration_label", "N/A")

                writer.writerow([
                    fixing_commit_code,
                    bug_inducing_commit_code,
                    fixing_label,
                    fixing_snippets,
                    fixing_cwes,
                    bug_label,
                    bug_snippets,
                    bug_cwes
                ])


                print(f"✅ Row {row_count} processed")
                if fixing_commit_code:
                    print(json.dumps(result_fixing, indent=4))
                sys.stdout.flush()

            except Exception as e:
                print(f"❌ Error at Row {row_count}: {e}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Loading model...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# The new lm_head weights will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# /usr/local/lib/python3.11/dist-packages/bitsandbytes/nn/modules.py:451: UserWarning: Input type into Linear4bit is torch.float16, but bnb_4bit_compute_dtype=torch.float32 (default). This will lead to slow inference or training speed.
#   warnings.warn(
# ✅ Row 1 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "haproxy",
#             "related_cwe": "CWE-937"
#         },
#         {
#             "misconfigured_snippet": "PyYAML",
#             "related_cwe": "CWE-1195"
#         },
#         {
#             "misconfigured_snippet": "python*-setuptools",
#             "related_cwe": "CWE-1196"
#         },
#         {
#             "misconfigured_snippet": "python-setuptools",
#             "related_cwe": "CWE-1196"
#         },
#         {
#             "misconfigured_snippet": "python",
#             "related_cwe": "CWE-1196"
#         },
#         {
#             "misconfigured_snippet": "pkg_extras",
#             "related_cwe": "CWE-1196"
#         },
#         {
#             "misconfigured_snippet": "python-setuptools",
#             "related_cwe": "CWE-1196"
#         },
#         {
#             "misconfigured_snippet": "python-setuptools",
#             "related_cwe": "CWE-1196"
#         },
#         {
#             "misconfigured_snippet": "pkg_extras",
#             "related_cwe": "CWE-1196"
#         },
#         {
#             "misconfigured_snippet": "pkg_extras",
#             "related_cwe": "CWE-1196"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 2 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "python*-setuptools",
#             "related_cwe": "CWE-123"
#         },
#         {
#             "misconfigured_snippet": "pkg_extras",
#             "related_cwe": "CWE-123"
#         },
#         {
#             "misconfigured_snippet": "python-setuptools",
#             "related_cwe": "CWE-123"
#         },
#         {
#             "misconfigured_snippet": "haproxy",
#             "related_cwe": "CWE-123"
#         },
#         {
#             "misconfigured_snippet": "PyYAML",
#             "related_cwe": "CWE-123"
#         },
#         {
#             "misconfigured_snippet": "pkg_extras: python-setuptools haproxy PyYAML",
#             "related_cwe": "CWE-123"
#         },
#         {
#             "misconfigured_snippet": "pkg_extras: python*-setuptools haproxy PyYAML",
#             "related_cwe": "CWE-123"
#         },
#         {
#             "misconfigured_snippet": "pkg_extras: python-setuptools",
#             "related_cwe": "CWE-123"
#         },
#         {
#             "misconfigured_snippet": "pkg_extras: python*-setuptools",
#             "related_cwe": "CWE-123"
#         },
#         {
#             "misconfigured_snippet": "pkg_extras: haproxy",
#             "related_cwe": "CWE-123"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 3 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "pkg_extras: python*-setuptools python*-enum python*-netaddr ruby PyYAML",
#             "related_cwe": "CWE-1195"
#         },
#         {
#             "misconfigured_snippet": "pkg_extras: python-setuptools python-enum34 python-netaddr epel-release ruby PyYAML",
#             "related_cwe": "CWE-1172"
#         },
#         {
#             "misconfigured_snippet": "pkg_extras: python-setuptools python-enum34 python-netaddr epel-release ruby PyYAML",
#             "related_cwe": "CWE-1023"
#         },
#         {
#             "misconfigured_snippet": "pkg_extras: python*-setuptools python*-enum python*-netaddr epel-release ruby PyYAML",
#             "related_cwe": "CWE-1024"
#         },
#         {
#             "misconfigured_snippet": "pkg_extras: python*-setuptools python*-enum python*-netaddr epel-release ruby PyYAML",
#             "related_cwe": "CWE-1187"
#         },
#         {
#             "misconfigured_snippet": "pkg_extras: python-setuptools python-enum34 python-netaddr epel-release ruby PyYAML",
#             "related_cwe": "CWE-1187"
#         },
#         {
#             "misconfigured_snippet": "pkg_extras: python-setuptools python-enum34 python-netaddr epel-release ruby PyYAML",
#             "related_cwe": "CWE-1185"
#         },
#         {
#             "misconfigured_snippet": "pkg_extras: python-setuptools python-enum34 python-netaddr epel-release ruby PyYAML",
#             "related_cwe": "CWE-1194"
#         },
#         {
#             "misconfigured_snippet": "pkg_extras: python*-setuptools python*-enum python*-netaddr epel-release ruby PyYAML",
#             "related_cwe": "CWE-1023"
#         },
#         {
#             "misconfigured_snippet": "pkg_extras: python*-setuptools python*-enum python*-netaddr epel-release ruby PyYAML",
#             "related_cwe": "CWE-1024"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 4 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "pkg_extras: python*-setuptools python*-enum python*-netaddr ruby PyYAML",
#             "related_cwe": "CWE-937"
#         },
#         {
#             "misconfigured_snippet": "pkg_extras: python*-setuptools python*-enum python*-netaddr ruby PyYAML",
#             "related_cwe": "CWE-937"
#         },
#         {
#             "misconfigured_snippet": "pkg_extras: python*-setuptools python*-enum python*-netaddr ruby PyYAML",
#             "related_cwe": "CWE-937"
#         },
#         {
#             "misconfigured_snippet": "pkg_extras: python*-setuptools python*-enum python*-netaddr ruby PyYAML",
#             "related_cwe": "CWE-937"
#         },
#         {
#             "misconfigured_snippet": "pkg_extras: python*-setuptools python*-enum python*-netaddr ruby PyYAML",
#             "related_cwe": "CWE-937"
#         },
#         {
#             "misconfigured_snippet": "pkg_extras: python*-setuptools python*-enum python*-netaddr ruby PyYAML",
#             "related_cwe": "CWE-937"
#         },
#         {
#             "misconfigured_snippet": "pkg_extras: python*-setuptools python*-enum python*-netaddr ruby PyYAML",
#             "related_cwe": "CWE-937"
#         },
#         {
#             "misconfigured_snippet": "pkg_extras: python*-setuptools python*-enum python*-netaddr ruby PyYAML",
#             "related_cwe": "CWE-937"
#         },
#         {
#             "misconfigured_snippet": "pkg_extras: python*-setuptools python*-enum python*-netaddr ruby PyYAML",
#             "related_cwe": "CWE-937"
#         },
#         {
#             "misconfigured_snippet": "pkg_extras: python*-setuptools python*-enum python*-netaddr ruby PyYAML",
#             "related_cwe": "CWE-937"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 5 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "name: \\",
#             "related_cwe": "CWE-25"
#         },
#         {
#             "misconfigured_snippet": "name: \\",
#             "related_cwe": "CWE-276"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\",
#             "related_cwe": "CWE-276"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\",
#             "related_cwe": "CWE-276"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-276"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-276"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-276"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-275"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-275"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-276"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 6 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "when: checkgiinstall.stdout!= \\",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "oracle_sw_unpack|bool\\\\nwhen: checkgiinstall.stdout!= \\\\",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "and oracle_sw_unpack|bool\\\\nwhen: checkgiinstall.stdout!= \\\\\\\\",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "when: checkgiinstall.stdout!= \\\\",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "when: checkgiinstall.stdout!= \\\\\\\\",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "when: checkgiinstall.stdout!= \\\\\\\\",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "when: checkgiinstall.stdout!= \\\\\\\\",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "when: checkgiinstall.stdout!= \\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "oracle_sw_unpack|bool\\\\\\\\nwhen: checkgiinstall.stdout!= \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "and oracle_sw_unpack|bool\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-732"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 7 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "object_privs={{ item.1.object_privs | default (omit) }}",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "grants={{ item.1.grants |default(omit) }}",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "object_privs={{ item.1.object_privs |default (omit) }}",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "grants={{ item.1.grants |default(omit) }}",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "object_privs={{ item.1.object_privs |default (omit) }}",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "grants={{ item.1.grants |default(omit) }}",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "object_privs={{ item.1.object_privs |default (omit) }}",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "grants={{ item.1.grants |default(omit) }}",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "grants={{ item.1.grants |default(omit) }}",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "object_privs={{ item.1.object_privs |default (omit) }}",
#             "related_cwe": "CWE-732"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 8 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "ovirt_api_facts_internal_25",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "ovirt_clusters_internal_24",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "ovirt_api_facts_internal_25",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "ovirt_clusters_internal_24",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "ovirt_api_facts_internal_25",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "ovirt_clusters_internal_24",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "ovirt_api_facts_internal_25",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "ovirt_clusters_internal_24",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "ovirt_api_facts_internal_25",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "ovirt_clusters_internal_24",
#             "related_cwe": "CWE-732"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 9 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "args: {}warn: falsecommand: engine-setup --accept-defaults --config-append={{\\t\\t\\t\\tanswer_file_path\\t\\t\\t\\t}} {{ offline }}",
#             "related_cwe": "CWE-319"
#         },
#         {
#             "misconfigured_snippet": "until: health_page is success",
#             "related_cwe": "CWE-20"
#         },
#         {
#             "misconfigured_snippet": "command: engine-setup --accept-defaults --config-append={{\\\\t\\\\t\\\\t\\\\tanswer_file_path\\\\t\\\\t\\\\t\\\\t}} {{ offline }}",
#             "related_cwe": "CWE-16"
#         },
#         {
#             "misconfigured_snippet": "command: engine-setup --accept-defaults --config-append={{\\\\t\\\\t\\\\t\\\\tanswer_file_path\\\\t\\\\t\\\\t\\\\t}} {{ offline }}",
#             "related_cwe": "CWE-20"
#         },
#         {
#             "misconfigured_snippet": "command: engine-setup --accept-defaults --config-append={{\\\\\\\\t\\\\\\\\t\\\\\\\\t\\\\\\\\tanswer_file_path\\\\\\\\t\\\\\\\\t\\\\\\\\t\\\\\\\\t}} {{ offline }}",
#             "related_cwe": "CWE-77"
#         },
#         {
#             "misconfigured_snippet": "command: engine-setup --accept-defaults --config-append={{\\\\t\\\\t\\\\t\\\\tanswer_file_path\\\\t\\\\t\\\\t\\\\t}} {{ offline }}",
#             "related_cwe": "CWE-20"
#         },
#         {
#             "misconfigured_snippet": "command: engine-setup --accept-defaults --config-append={{\\\\t\\\\t\\\\t\\\\tanswer_file_path\\\\t\\\\t\\\\t\\\\t}} {{ offline }}",
#             "related_cwe": "CWE-16"
#         },
#         {
#             "misconfigured_snippet": "command: engine-setup --accept-defaults --config-append={{\\\\\\\\t\\\\\\\\t\\\\\\\\t\\\\\\\\tanswer_file_path\\\\\\\\t\\\\\\\\t\\\\\\\\t\\\\\\\\t}} {{ offline }}",
#             "related_cwe": "CWE-77"
#         },
#         {
#             "misconfigured_snippet": "command: engine-setup --accept-defaults --config-append={{\\\\\\\\\\\\\\\\t\\\\\\\\\\\\\\\\t\\\\\\\\\\\\\\\\t\\\\\\\\\\\\\\\\tanswer_file_path\\\\\\\\\\\\\\\\t\\\\\\\\\\\\\\\\t\\\\\\\\\\\\\\\\t\\\\\\\\\\\\\\\\t}} {{ offline }}",
#             "related_cwe": "CWE-77"
#         },
#         {
#             "misconfigured_snippet": "command: engine-setup --accept-defaults --config-append={{\\\\\\\\t\\\\\\\\t\\\\\\\\t\\\\\\\\tanswer_file_path\\\\\\\\t\\\\\\\\t\\\\\\\\t\\\\\\\\t}} {{ offline }}",
#             "related_cwe": "CWE-77"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 10 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "ansible_user: null",
#             "related_cwe": "CWE-250"
#         },
#         {
#             "misconfigured_snippet": "no_log: false",
#             "related_cwe": "CWE-307"
#         },
#         {
#             "misconfigured_snippet": "become: true",
#             "related_cwe": "CWE-250"
#         },
#         {
#             "misconfigured_snippet": "become_method: sudo",
#             "related_cwe": "CWE-250"
#         },
#         {
#             "misconfigured_snippet": "become_user: root",
#             "related_cwe": "CWE-250"
#         },
#         {
#             "misconfigured_snippet": "gather_facts: yes",
#             "related_cwe": "CWE-250"
#         },
#         {
#             "misconfigured_snippet": "gather_facts: yes",
#             "related_cwe": "CWE-250"
#         },
#         {
#             "misconfigured_snippet": "vars_files",
#             "related_cwe": "CWE-306"
#         },
#         {
#             "misconfigured_snippet": "tags",
#             "related_cwe": "CWE-306"
#         },
#         {
#             "misconfigured_snippet": "vars_files",
#             "related_cwe": "CWE-306"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 11 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "regexp: nzb_backup_dir =",
#             "related_cwe": "CWE-264"
#         },
#         {
#             "misconfigured_snippet": "regexp: nzb_backup_dir =",
#             "related_cwe": "CWE-264"
#         },
#         {
#             "misconfigured_snippet": "regexp: nzb_backup_dir =",
#             "related_cwe": "CWE-264"
#         },
#         {
#             "misconfigured_snippet": "regexp: nzb_backup_dir =",
#             "related_cwe": "CWE-264"
#         },
#         {
#             "misconfigured_snippet": "regexp: nzb_backup_dir =",
#             "related_cwe": "CWE-264"
#         },
#         {
#             "misconfigured_snippet": "regexp: nzb_backup_dir =",
#             "related_cwe": "CWE-264"
#         },
#         {
#             "misconfigured_snippet": "regexp: nzb_backup_dir =",
#             "related_cwe": "CWE-264"
#         },
#         {
#             "misconfigured_snippet": "regexp: nzb_backup_dir =",
#             "related_cwe": "CWE-264"
#         },
#         {
#             "misconfigured_snippet": "regexp: nzb_backup_dir =",
#             "related_cwe": "CWE-264"
#         },
#         {
#             "misconfigured_snippet": "regexp: nzb_backup_dir =",
#             "related_cwe": "CWE-264"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 12 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "default_vault",
#             "related_cwe": "CWE-345"
#         },
#         {
#             "misconfigured_snippet": "var ansible_connection",
#             "related_cwe": "CWE-287"
#         },
#         {
#             "misconfigured_snippet": "default_vault",
#             "related_cwe": "CWE-345"
#         },
#         {
#             "misconfigured_snippet": "vars",
#             "related_cwe": "CWE-256"
#         },
#         {
#             "misconfigured_snippet": "default_vault",
#             "related_cwe": "CWE-345"
#         },
#         {
#             "misconfigured_snippet": "default_vault",
#             "related_cwe": "CWE-345"
#         },
#         {
#             "misconfigured_snippet": "vars",
#             "related_cwe": "CWE-256"
#         },
#         {
#             "misconfigured_snippet": "default_vault",
#             "related_cwe": "CWE-345"
#         },
#         {
#             "misconfigured_snippet": "default_vault",
#             "related_cwe": "CWE-345"
#         },
#         {
#             "misconfigured_snippet": "vars",
#             "related_cwe": "CWE-256"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 13 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "when: updatecheck.stdout == \\",
#             "related_cwe": "CWE-1031"
#         },
#         {
#             "misconfigured_snippet": "if updatecheck.stdout == \\\\",
#             "related_cwe": "CWE-1031"
#         },
#         {
#             "misconfigured_snippet": "when: updatecheck.stdout == \\\\",
#             "related_cwe": "CWE-1031"
#         },
#         {
#             "misconfigured_snippet": "when: updatecheck.stdout == \\\\\\\\",
#             "related_cwe": "CWE-1031"
#         },
#         {
#             "misconfigured_snippet": "when: updatecheck.stdout == \\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-1031"
#         },
#         {
#             "misconfigured_snippet": "when: updatecheck.stdout == 18.09.2,\\\\\\n\\",
#             "related_cwe": "CWE-1031"
#         },
#         {
#             "misconfigured_snippet": "when: updatecheck.stdout == 18.09.2,\\\\\\n\\\\",
#             "related_cwe": "CWE-1031"
#         },
#         {
#             "misconfigured_snippet": "when: updatecheck.stdout == 18.09.2,\\\\\\\\\\\\n\\\\t",
#             "related_cwe": "CWE-1031"
#         },
#         {
#             "misconfigured_snippet": "when: updatecheck.stdout == 18.09.2,\\\\\\\\\\\\\\\\\\\\\\\\n\\\\\\\\t\\\\\\\\n",
#             "related_cwe": "CWE-1031"
#         },
#         {
#             "misconfigured_snippet": "when: updatecheck.stdout == 18.09.2,\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n\\\\\\\\\\\\\\\\t\\\\\\\\\\\\\\\\n\\\\\\\\",
#             "related_cwe": "CWE-1031"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 14 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "traefik.frontend.rule: \\",
#             "related_cwe": "CWE-23"
#         },
#         {
#             "misconfigured_snippet": "Host:heimdall.{{domain.stdout}}",
#             "related_cwe": "CWE-89"
#         },
#         {
#             "misconfigured_snippet": "Host:heimdall.{{domain.stdout}}",
#             "related_cwe": "CWE-20"
#         },
#         {
#             "misconfigured_snippet": "traefik.frontend.rule: \\\\",
#             "related_cwe": "CWE-89"
#         },
#         {
#             "misconfigured_snippet": "traefik.frontend.rule: \\\\",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "traefik.frontend.rule: \\\\\\\\",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "traefik.frontend.rule: \\\\\\\\",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "traefik.frontend.rule: \\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "traefik.frontend.rule: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "traefik.frontend.rule: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-732"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 15 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "nan",
#             "related_cwe": "N/A"
#         },
#         {
#             "misconfigured_snippet": "nan",
#             "related_cwe": "N/A"
#         },
#         {
#             "misconfigured_snippet": "nan",
#             "related_cwe": "N/A"
#         },
#         {
#             "misconfigured_snippet": "nan",
#             "related_cwe": "N/A"
#         },
#         {
#             "misconfigured_snippet": "nan",
#             "related_cwe": "N/A"
#         },
#         {
#             "misconfigured_snippet": "nan",
#             "related_cwe": "N/A"
#         },
#         {
#             "misconfigured_snippet": "nan",
#             "related_cwe": "N/A"
#         },
#         {
#             "misconfigured_snippet": "nan",
#             "related_cwe": "N/A"
#         },
#         {
#             "misconfigured_snippet": "nan",
#             "related_cwe": "N/A"
#         },
#         {
#             "misconfigured_snippet": "nan",
#             "related_cwe": "N/A"
#         }
#     ],
#     "misconfiguration_label": "N/A"
# }
# ✅ Row 16 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "- name: 'task_name'",
#             "related_cwe": "CWE-123"
#         },
#         {
#             "misconfigured_snippet": "when: 'expression'",
#             "related_cwe": "CWE-123"
#         },
#         {
#             "misconfigured_snippet": "loop: 'range'",
#             "related_cwe": "CWE-123"
#         },
#         {
#             "misconfigured_snippet": "loop: 'list'",
#             "related_cwe": "CWE-123"
#         },
#         {
#             "misconfigured_snippet": "with: 'dictionary'",
#             "related_cwe": "CWE-123"
#         },
#         {
#             "misconfigured_snippet": "set_fact: 'var_name'",
#             "related_cwe": "CWE-123"
#         },
#         {
#             "misconfigured_snippet": "run_once: 'True'",
#             "related_cwe": "CWE-123"
#         },
#         {
#             "misconfigured_snippet": "become: 'true'",
#             "related_cwe": "CWE-123"
#         },
#         {
#             "misconfigured_snippet": "become_user: 'user'",
#             "related_cwe": "CWE-123"
#         },
#         {
#             "misconfigured_snippet": "become_method:'sudo'",
#             "related_cwe": "CWE-123"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 17 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "443:443",
#             "related_cwe": "CWE-123"
#         },
#         {
#             "misconfigured_snippet": "443:443",
#             "related_cwe": "CWE-123"
#         },
#         {
#             "misconfigured_snippet": "443:443",
#             "related_cwe": "CWE-123"
#         },
#         {
#             "misconfigured_snippet": "443:443",
#             "related_cwe": "CWE-123"
#         },
#         {
#             "misconfigured_snippet": "443:443",
#             "related_cwe": "CWE-123"
#         },
#         {
#             "misconfigured_snippet": "443:443",
#             "related_cwe": "CWE-123"
#         },
#         {
#             "misconfigured_snippet": "443:443",
#             "related_cwe": "CWE-123"
#         },
#         {
#             "misconfigured_snippet": "443:443",
#             "related_cwe": "CWE-123"
#         },
#         {
#             "misconfigured_snippet": "443:443",
#             "related_cwe": "CWE-123"
#         },
#         {
#             "misconfigured_snippet": "443:443",
#             "related_cwe": "CWE-123"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 18 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "vars: {username: user},\\n  group: {group_name: group_name}",
#             "related_cwe": "CWE-306"
#         },
#         {
#             "misconfigured_snippet": "tasks: {tasks: task_1,\\\\n  task_2,\\\\n  task_3},\\\\n  task_1: {cmd: whoami},\\\\n  task_2: {cmd: whoami},\\\\n  task_3: {cmd: whoami,\\\\n  register: user},\\\\n  hosts: {all: localhost},\\\\n  gather_facts: true,\\\\n  become: true,\\\\n  become_user: user,\\\\n  become_method: sudo",
#             "related_cwe": "CWE-307"
#         },
#         {
#             "misconfigured_snippet": "vars: {username: user},\\\\n  group: {group_name: group_name}",
#             "related_cwe": "CWE-308"
#         },
#         {
#             "misconfigured_snippet": "tasks: {tasks: task_1,\\\\\\\\n  task_2,\\\\\\\\n  task_3},\\\\\\\\n  task_1: {cmd: whoami},\\\\\\\\n  task_2: {cmd: whoami},\\\\\\\\n  task_3: {cmd: whoami,\\\\\\\\n  register: user},\\\\\\\\n  hosts: {all: localhost},\\\\\\\\n  gather_facts: true,\\\\\\\\n  become: true,\\\\\\\\n  become_user: user,\\\\\\\\n  become_method: sudo",
#             "related_cwe": "CWE-312"
#         },
#         {
#             "misconfigured_snippet": "tasks: {tasks: task_1,\\\\\\\\n  task_2,\\\\\\\\n  task_3},\\\\\\\\n  task_1: {cmd: whoami},\\\\\\\\n  task_2: {cmd: whoami},\\\\\\\\n  task_3: {cmd: whoami,\\\\\\\\n  register: user},\\\\\\\\n  hosts: {all: localhost},\\\\\\\\n  gather_facts: true,\\\\\\\\n  become: true,\\\\\\\\n  become_user: user,\\\\\\\\n  become_method: sudo",
#             "related_cwe": "CWE-328"
#         },
#         {
#             "misconfigured_snippet": "tasks: {tasks: task_1,\\\\\\\\\\\\\\\\n  task_2,\\\\\\\\\\\\\\\\n  task_3},\\\\\\\\\\\\\\\\n  task_1: {cmd: whoami},\\\\\\\\\\\\\\\\n  task_2: {cmd: whoami},\\\\\\\\\\\\\\\\n  task_3: {cmd: whoami,\\\\\\\\\\\\\\\\n  register: user},\\\\\\\\\\\\\\\\n  hosts: {all: localhost},\\\\\\\\\\\\\\\\n  gather_facts: true,\\\\\\\\\\\\\\\\n  become: true,\\\\\\\\\\\\\\\\n  become_user: user,\\\\\\\\\\\\\\\\n  become_method: sudo",
#             "related_cwe": "CWE-334"
#         },
#         {
#             "misconfigured_snippet": "tasks: {tasks: task_1,\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n  task_2,\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n  task_3},\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n  task_1: {cmd: whoami},\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n  task_2: {cmd: whoami},\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n  task_3: {cmd: whoami,\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n  register: user},\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n  hosts: {all: localhost},\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n  gather_facts: true,\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n  become: true,\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n  become_user: user,\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n ",
#             "related_cwe": "CWE-352"
#         },
#         {
#             "misconfigured_snippet": "tasks: {tasks: task_1,\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n  task_2,\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n  task_3},\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n  task_1: {cmd: whoami},\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n  task_2: {cmd: whoami},\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n  task_3: {cmd: whoami,\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n  register: user},\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n  hosts: {all: localhost},\\\\\\\\",
#             "related_cwe": "CWE-367"
#         },
#         {
#             "misconfigured_snippet": "tasks: {tasks: task_1,\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n  task_2,\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n  task_3},\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n  task_1: {cmd: whoami},\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-380"
#         },
#         {
#             "misconfigured_snippet": "tasks: {tasks: task_1,\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-396"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 19 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "enable-telemetry: true",
#             "related_cwe": "CWE-269"
#         },
#         {
#             "misconfigured_snippet": "disable_teletmetry: false",
#             "related_cwe": "CWE-290"
#         },
#         {
#             "misconfigured_snippet": "enable-telemetry: true",
#             "related_cwe": "CWE-276"
#         },
#         {
#             "misconfigured_snippet": "disable_telemetry: false",
#             "related_cwe": "CWE-290"
#         },
#         {
#             "misconfigured_snippet": "disable_telemetry: true",
#             "related_cwe": "CWE-275"
#         },
#         {
#             "misconfigured_snippet": "enable_teletmetry: false",
#             "related_cwe": "CWE-275"
#         },
#         {
#             "misconfigured_snippet": "disable_telemetry: true",
#             "related_cwe": "CWE-275"
#         },
#         {
#             "misconfigured_snippet": "enable_teletmetry: false",
#             "related_cwe": "CWE-275"
#         },
#         {
#             "misconfigured_snippet": "disable_telemetry: false",
#             "related_cwe": "CWE-290"
#         },
#         {
#             "misconfigured_snippet": "enable_teletmetry: true",
#             "related_cwe": "CWE-269"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 20 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "increase(tidb_server_event_total{type=~",
#             "related_cwe": "CWE-758"
#         },
#         {
#             "misconfigured_snippet": "increase(tidb_server_event_total{type=~",
#             "related_cwe": "CWE-758"
#         },
#         {
#             "misconfigured_snippet": "increase( tidb_tikvclient_backoff_total[10m] )  > 10",
#             "related_cwe": "CWE-758"
#         },
#         {
#             "misconfigured_snippet": "increase( tidb_tikvclient_backoff_total[10m] )  > 10",
#             "related_cwe": "CWE-758"
#         },
#         {
#             "misconfigured_snippet": "increase( tidb_tikvclient_backoff_total[10m] )  > 10",
#             "related_cwe": "CWE-758"
#         },
#         {
#             "misconfigured_snippet": "increase( tidb_tikvclient_backoff_total[10m] )  > 10",
#             "related_cwe": "CWE-758"
#         },
#         {
#             "misconfigured_snippet": "increase( tidb_tikvclient_backoff_total[10m] )  > 10",
#             "related_cwe": "CWE-758"
#         },
#         {
#             "misconfigured_snippet": "increase( tidb_tikvclient_backoff_total[10m] )  > 10",
#             "related_cwe": "CWE-758"
#         },
#         {
#             "misconfigured_snippet": "increase( tidb_tikvclient_backoff_total[10m] )  > 10",
#             "related_cwe": "CWE-758"
#         },
#         {
#             "misconfigured_snippet": "increase( tidb_tikvclient_backoff_total[10m] )  > 10",
#             "related_cwe": "CWE-758"
#         }
#     ],
#     "misconfiguration_label": "0"
# }
# ✅ Row 21 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "- name: example",
#             "related_cwe": "CWE-119"
#         },
#         {
#             "misconfigured_snippet": "- name: example",
#             "related_cwe": "CWE-119"
#         },
#         {
#             "misconfigured_snippet": "name: example",
#             "related_cwe": "CWE-190"
#         },
#         {
#             "misconfigured_snippet": "name: example",
#             "related_cwe": "CWE-190"
#         },
#         {
#             "misconfigured_snippet": "name: example",
#             "related_cwe": "CWE-190"
#         },
#         {
#             "misconfigured_snippet": "name: example",
#             "related_cwe": "CWE-190"
#         },
#         {
#             "misconfigured_snippet": "name: example",
#             "related_cwe": "CWE-190"
#         },
#         {
#             "misconfigured_snippet": "name: example",
#             "related_cwe": "CWE-190"
#         },
#         {
#             "misconfigured_snippet": "name: example",
#             "related_cwe": "CWE-190"
#         },
#         {
#             "misconfigured_snippet": "name: example",
#             "related_cwe": "CWE-190"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 22 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "block:",
#             "related_cwe": "CWE-732"
#         },
#         {
#             "misconfigured_snippet": "name: Ensure control node address is registered in Ansible",
#             "related_cwe": "CWE-269"
#         },
#         {
#             "misconfigured_snippet": "register: k3s_control_delegate_raw",
#             "related_cwe": "CWE-284"
#         },
#         {
#             "misconfigured_snippet": "command: 'grep 'P_True' if (k3s_controller_count | length > 1) else 'C_True' /tmp/inventory.txt'",
#             "related_cwe": "CWE-120"
#         },
#         {
#             "misconfigured_snippet": "set_fact: k3s_control_delegate_raw",
#             "related_cwe": "CWE-276"
#         },
#         {
#             "misconfigured_snippet": "name: Ensure the control node address is registered in Ansible",
#             "related_cwe": "CWE-275"
#         },
#         {
#             "misconfigured_snippet": "name: Lookup control node from file",
#             "related_cwe": "CWE-285"
#         },
#         {
#             "misconfigured_snippet": "set_fact: k3s_control_node_address",
#             "related_cwe": "CWE-275"
#         },
#         {
#             "misconfigured_snippet": "set_fact: k3s_control_delegate",
#             "related_cwe": "CWE-276"
#         },
#         {
#             "misconfigured_snippet": "set_fact: k3s_control_delegate",
#             "related_cwe": "CWE-269"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 23 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "zone: \\",
#             "related_cwe": "CWE-25"
#         },
#         {
#             "misconfigured_snippet": "zone: \\\\\\",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "zone: \\\\\\\\\\\\\\",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "zone: \\\\\\",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "zone: \\\\\\\\\\\\",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "zone: \\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "zone: \\\\\\\\\\\\",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "zone: \\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "zone: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "zone: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-22"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 24 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "role: update-host\\n  tags:",
#             "related_cwe": "CWE-89"
#         },
#         {
#             "misconfigured_snippet": "role: rhsm\\\\n- configure_rhsm",
#             "related_cwe": "CWE-250"
#         },
#         {
#             "misconfigured_snippet": "role: config-bonding",
#             "related_cwe": "CWE-256"
#         },
#         {
#             "misconfigured_snippet": "role: config-vlans",
#             "related_cwe": "CWE-256"
#         },
#         {
#             "misconfigured_snippet": "role: config-routes",
#             "related_cwe": "CWE-256"
#         },
#         {
#             "misconfigured_snippet": "role: config-iscsi-client",
#             "related_cwe": "CWE-251"
#         },
#         {
#             "misconfigured_snippet": "role: config-iscsi-client",
#             "related_cwe": "CWE-254"
#         },
#         {
#             "misconfigured_snippet": "role: config-iscsi-client",
#             "related_cwe": "CWE-120"
#         },
#         {
#             "misconfigured_snippet": "role: config-iscsi-client",
#             "related_cwe": "CWE-253"
#         },
#         {
#             "misconfigured_snippet": "role: config-iscsi-client",
#             "related_cwe": "CWE-254"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 25 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "body_format: json\\nbody:\\n  name: \\",
#             "related_cwe": "CWE-120"
#         },
#         {
#             "misconfigured_snippet": "description: \\\\",
#             "related_cwe": "CWE-120"
#         },
#         {
#             "misconfigured_snippet": "permissions: \\\\",
#             "related_cwe": "CWE-120"
#         },
#         {
#             "misconfigured_snippet": "register: permission_scheme_output\\\\n\\\\n\\\\ndefault_permission_scheme_id: \\\\\\\\",
#             "related_cwe": "CWE-120"
#         },
#         {
#             "misconfigured_snippet": "permission_scheme_output.json.id \\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-120"
#         },
#         {
#             "misconfigured_snippet": "name: \\",
#             "related_cwe": "CWE-120"
#         },
#         {
#             "misconfigured_snippet": "description: \\\\",
#             "related_cwe": "CWE-120"
#         },
#         {
#             "misconfigured_snippet": "permissions: \\\\\\\\",
#             "related_cwe": "CWE-120"
#         },
#         {
#             "misconfigured_snippet": "register: permission_scheme_output\\\\\\\\n\\\\\\\\n\\\\\\\\ndefault_permission_scheme_id: \\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-120"
#         },
#         {
#             "misconfigured_snippet": "permission_scheme_output.json.id \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n\\",
#             "related_cwe": "CWE-120"
#         }
#     ],
# ...
#             "related_cwe": "CWE-779"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-779"
#         },
#         {
#             "misconfigured_snippet": "name: \\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-778"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 88 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "mode: 0644\\n",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "group: 'root'",
#             "related_cwe": "CWE-221"
#         },
#         {
#             "misconfigured_snippet": "owner: 'root'",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "mode: 0644\\\\n",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "group: 'root'",
#             "related_cwe": "CWE-221"
#         },
#         {
#             "misconfigured_snippet": "owner: 'root'",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "mode: 0644\\\\n",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "group: 'root'",
#             "related_cwe": "CWE-221"
#         },
#         {
#             "misconfigured_snippet": "owner: 'root'",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "mode: 0644",
#             "related_cwe": "CWE-22"
#         }
#     ],
#     "misconfiguration_label": "0"
# }
# ✅ Row 89 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "irods-rule-engine-plugin-python-4.2.8.0-1",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "irods-rule-engine-plugin-python-4.2.8.0-1",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "irods-rule-engine-plugin-python-4.2.8.0-1",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "irods-rule-engine-plugin-python-4.2.8.0-1",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "irods-rule-engine-plugin-python-4.2.8.0-1",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "irods-rule-engine-plugin-python-4.2.8.0-1",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "irods-rule-engine-plugin-python-4.2.8.0-1",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "irods-rule-engine-plugin-python-4.2.8.0-1",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "irods-rule-engine-plugin-python-4.2.8.0-1",
#             "related_cwe": "CWE-22"
#         },
#         {
#             "misconfigured_snippet": "irods-rule-engine-plugin-python-4.2.8.0-1",
#             "related_cwe": "CWE-22"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 90 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "when: ruleset.install_scripts and install_rulesets",
#             "related_cwe": "CWE-1031"
#         },
#         {
#             "misconfigured_snippet": "when: ruleset.install_scripts and install_rulesets",
#             "related_cwe": "CWE-1033"
#         },
#         {
#             "misconfigured_snippet": "when: ruleset.install_scripts and install_rulesets",
#             "related_cwe": "CWE-1034"
#         },
#         {
#             "misconfigured_snippet": "when: ruleset.install_scripts and install_rulesets",
#             "related_cwe": "CWE-1044"
#         },
#         {
#             "misconfigured_snippet": "when: ruleset.install_scripts and install_rulesets",
#             "related_cwe": "CWE-1049"
#         },
#         {
#             "misconfigured_snippet": "when: ruleset.install_scripts and install_rulesets",
#             "related_cwe": "CWE-1052"
#         },
#         {
#             "misconfigured_snippet": "when: ruleset.install_scripts and install_rulesets",
#             "related_cwe": "CWE-1091"
#         },
#         {
#             "misconfigured_snippet": "when: ruleset.install_scripts and install_rulesets",
#             "related_cwe": "CWE-1247"
#         },
#         {
#             "misconfigured_snippet": "when: ruleset.install_scripts and install_rulesets",
#             "related_cwe": "CWE-1254"
#         },
#         {
#             "misconfigured_snippet": "when: ruleset.install_scripts and install_rulesets",
#             "related_cwe": "CWE-1304"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 91 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "vars:\\n    ansible_host: localhost",
#             "related_cwe": "CWE-190"
#         },
#         {
#             "misconfigured_snippet": "hosts: localhost",
#             "related_cwe": "CWE-319"
#         },
#         {
#             "misconfigured_snippet": "become: yes",
#             "related_cwe": "CWE-275"
#         },
#         {
#             "misconfigured_snippet": "roles:\\\\n  - {role: ansible-role-viasite-zsh-config}",
#             "related_cwe": "CWE-327"
#         },
#         {
#             "misconfigured_snippet": "- hosts: localhost\\\\n      roles:\\\\n        - {role: ansible-role-viasite-zsh-config}",
#             "related_cwe": "CWE-327"
#         },
#         {
#             "misconfigured_snippet": "name: Create local user",
#             "related_cwe": "CWE-295"
#         },
#         {
#             "misconfigured_snippet": "name: Create home directory for local user",
#             "related_cwe": "CWE-276"
#         },
#         {
#             "misconfigured_snippet": "name: Create home directory for local user\\\\n      sudo: yes",
#             "related_cwe": "CWE-276"
#         },
#         {
#             "misconfigured_snippet": "name: Change owner of home directory to local user",
#             "related_cwe": "CWE-276"
#         },
#         {
#             "misconfigured_snippet": "name: Change owner of home directory to local user\\\\\\\\n      sudo: yes",
#             "related_cwe": "CWE-276"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 92 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "ansible_playbook",
#             "related_cwe": "CWE-601"
#         },
#         {
#             "misconfigured_snippet": "master or worker",
#             "related_cwe": "CWE-601"
#         },
#         {
#             "misconfigured_snippet": "if",
#             "related_cwe": "CWE-1037"
#         },
#         {
#             "misconfigured_snippet": "wazuh_manager_config.cluster",
#             "related_cwe": "CWE-601"
#         },
#         {
#             "misconfigured_snippet": "wazuh_manager_config.cluster.node_type",
#             "related_cwe": "CWE-601"
#         },
#         {
#             "misconfigured_snippet": "wazuh_manager_config.cluster.node_type == \\",
#             "related_cwe": "CWE-1037"
#         },
#         {
#             "misconfigured_snippet": "wazuh_manager_config.cluster.node_type == \\",
#             "related_cwe": "CWE-1037"
#         },
#         {
#             "misconfigured_snippet": "wazuh_manager_config.cluster.node_type == \\",
#             "related_cwe": "CWE-1037"
#         },
#         {
#             "misconfigured_snippet": "wazuh_manager_config.cluster.node_type == \\\\",
#             "related_cwe": "CWE-1037"
#         },
#         {
#             "misconfigured_snippet": "wazuh_manager_config.cluster.node_type == \\\\\\\\",
#             "related_cwe": "CWE-1037"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 93 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "baseurl: \\",
#             "related_cwe": "CWE-1196"
#         },
#         {
#             "misconfigured_snippet": "gpgkey: \\\\",
#             "related_cwe": "CWE-1196"
#         },
#         {
#             "misconfigured_snippet": "baseurl: \\\\",
#             "related_cwe": "CWE-1196"
#         },
#         {
#             "misconfigured_snippet": "gpgkey: \\\\\\\\",
#             "related_cwe": "CWE-1196"
#         },
#         {
#             "misconfigured_snippet": "baseurl: \\\\",
#             "related_cwe": "CWE-1196"
#         },
#         {
#             "misconfigured_snippet": "gpgkey: \\\\",
#             "related_cwe": "CWE-1196"
#         },
#         {
#             "misconfigured_snippet": "baseurl: \\\\\\\\",
#             "related_cwe": "CWE-1196"
#         },
#         {
#             "misconfigured_snippet": "gpgkey: \\\\\\\\",
#             "related_cwe": "CWE-1196"
#         },
#         {
#             "misconfigured_snippet": "baseurl: \\\\\\\\",
#             "related_cwe": "CWE-1196"
#         },
#         {
#             "misconfigured_snippet": "gpgkey: \\\\\\\\\\\\",
#             "related_cwe": "CWE-1196"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 94 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "vars:\\n  - {elasticsearch_node_name}",
#             "related_cwe": "CWE-190"
#         },
#         {
#             "misconfigured_snippet": "vars:\\\\n  - {kibana_node_name}",
#             "related_cwe": "CWE-190"
#         },
#         {
#             "misconfigured_snippet": "vars:\\\\n  - {kibana_node_name}",
#             "related_cwe": "CWE-190"
#         },
#         {
#             "misconfigured_snippet": "vars:\\\\n  - {kibana_node_name}",
#             "related_cwe": "CWE-190"
#         },
#         {
#             "misconfigured_snippet": "vars:\\\\\\\\n  - {kibana_node_name}",
#             "related_cwe": "CWE-190"
#         },
#         {
#             "misconfigured_snippet": "vars:\\\\\\\\\\\\\\\\\\\\n  - {kibana_node_name}",
#             "related_cwe": "CWE-190"
#         },
#         {
#             "misconfigured_snippet": "vars:\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n  - {kibana_node_name}",
#             "related_cwe": "CWE-190"
#         },
#         {
#             "misconfigured_snippet": "vars:\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n  - {kibana_node_name}",
#             "related_cwe": "CWE-190"
#         },
#         {
#             "misconfigured_snippet": "vars:\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\n  - {kibana_node_name}",
#             "related_cwe": "CWE-190"
#         },
#         {
#             "misconfigured_snippet": "vars:\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",
#             "related_cwe": "CWE-190"
#         }
#     ],
#     "misconfiguration_label": "1"
# }
# ✅ Row 95 processed
# {
#     "issues_found": [
#         {
#             "misconfigured_snippet": "ansible_os_family",
#             "related_cwe": "CWE-829"
#         },
#         {
#             "misconfigured_snippet": "ansible_os_family",
#             "related_cwe": "CWE-1043"
#         },
#         {
#             "misconfigured_snippet": "ansible_os_family",
#             "related_cwe": "CWE-829"
#         },
#         {
#             "misconfigured_snippet": "ansible_os_family",
#             "related_cwe": "CWE-829"
#         },
#         {
#             "misconfigured_snippet": "ansible_os_family",
#             "related_cwe": "CWE-1043"
#         },
#         {
#             "misconfigured_snippet": "ansible_os_family",
#             "related_cwe": "CWE-829"
#         },
#         {
#             "misconfigured_snippet": "ansible_os_family",
#             "related_cwe": "CWE-829"
#         },
#         {
#             "misconfigured_snippet": "ansible_os_family",
#             "related_cwe": "CWE-829"
#         },
#         {
#             "misconfigured_snippet": "ansible_os_family",
#             "related_cwe": "CWE-829"
#         },
#         {
#             "misconfigured_snippet": "ansible_os_family",
#             "related_cwe": "CWE-829"
#         }
#     ],
#     "misconfiguration_label": "1"
# }

# %%
# !pip install bitsandbytes
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: torch<3,>=2.0 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.6.0+cu124)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3,>=2.0->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3,>=2.0->bitsandbytes) (3.0.2)
# Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl (76.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 32.8 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.45.5

# %%
# Use Python 3.8 (or 3.7 if possible)
# !pip install torch==1.13.1
# !pip install https://storage.googleapis.com/tpu-pytorch/wheels/torch_xla-1.13-cp38-cp38-linux_x86_64.whl
# Out:
# Collecting torch==1.13.1
#   Downloading torch-1.13.1-cp311-cp311-manylinux1_x86_64.whl.metadata (24 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch==1.13.1) (4.13.2)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch==1.13.1)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch==1.13.1)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch==1.13.1)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch==1.13.1)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1) (75.2.0)
# Collecting wheel (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1)
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Downloading torch-1.13.1-cp311-cp311-manylinux1_x86_64.whl (887.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.4/887.4 MB 1.9 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 11.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 131.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 70.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.4 MB/s eta 0:00:00
# Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 6.8 MB/s eta 0:00:00
# Installing collected packages: wheel, nvidia-cuda-nvrtc-cu11, nvidia-cuda-runtime-cu11, nvidia-cublas-cu11, nvidia-cudnn-cu11, torch
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1
#     Uninstalling torch-2.5.1:
#       Successfully uninstalled torch-2.5.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.20.1 requires torch==2.5.1, but you have torch 1.13.1 which is incompatible.
# torchaudio 2.6.0+cpu requires torch==2.6.0, but you have torch 1.13.1 which is incompatible.
# accelerate 1.6.0 requires torch>=2.0.0, but you have torch 1.13.1 which is incompatible.
# Successfully installed nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 torch-1.13.1 wheel-0.45.1
# ERROR: torch_xla-1.13-cp38-cp38-linux_x86_64.whl is not a supported wheel on this platform.

# %%
# !pip install transformers==4.48.3
# Out:
# Collecting transformers==4.48.3
#   Downloading transformers-4.48.3-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (0.31.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.48.3) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers==4.48.3) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers==4.48.3) (4.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers==4.48.3) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.48.3) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.48.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.48.3) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.48.3) (2025.4.26)
# Downloading transformers-4.48.3-py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 68.7 MB/s eta 0:00:00
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.51.3
#     Uninstalling transformers-4.51.3:
#       Successfully uninstalled transformers-4.51.3
# Successfully installed transformers-4.48.3

# %%
# !pip install torch==2.5.1 torchvision==0.20.1
# Out:
# Collecting torch==2.5.1
#   Using cached torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting torchvision==0.20.1
#   Using cached torchvision-0.20.1-cp311-cp311-manylinux1_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch==2.5.1)
#   Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch==2.5.1)
#   Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch==2.5.1)
#   Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch==2.5.1)
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch==2.5.1)
#   Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch==2.5.1)
#   Using cached nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch==2.5.1)
#   Using cached nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch==2.5.1)
#   Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch==2.5.1)
#   Using cached nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch==2.5.1)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.1.0 (from torch==2.5.1)
#   Using cached triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (1.13.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision==0.20.1) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision==0.20.1) (11.2.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch==2.5.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.5.1) (3.0.2)
# Using cached torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl (906.5 MB)
# Using cached torchvision-0.20.1-cp311-cp311-manylinux1_x86_64.whl (7.2 MB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 124.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 108.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 43.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.7 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 108.3 MB/s eta 0:00:00
# Downloading triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 4.8 MB/s eta 0:00:00
# Installing collected packages: triton, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchvision
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0+cu124
#     Uninstalling torch-2.6.0+cu124:
#       Successfully uninstalled torch-2.6.0+cu124
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.21.0+cu124
#     Uninstalling torchvision-0.21.0+cu124:
#       Successfully uninstalled torchvision-0.21.0+cu124
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.6.0+cu124 requires torch==2.6.0, but you have torch 2.5.1 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 torch-2.5.1 torchvision-0.20.1 triton-3.1.0

# %%
# !rm torchvision.py
# Out:
# rm: cannot remove 'torchvision.py': No such file or directory

# %%
pip install transformers accelerate bitsandbytes
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.48.3)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.6.0)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.31.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.5.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (1.1.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl (76.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 32.3 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.45.5

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# STEP 2: Import pandas

import pandas as pd

# STEP 3: Set file paths (edit to your file locations)
file1_path = '/content/drive/MyDrive/expermintstarcoder/ansible_final/Ansible_Misconfig_Results_part2.csv'
file2_path = '/content/drive/MyDrive/expermintstarcoder/ansible_final/final-ansible_dataset_befor_varification.csv'

# STEP 4: Read both CSV files
df1 = pd.read_csv(file1_path)
df2 = pd.read_csv(file2_path)

# STEP 5: (Optional) Align column order if needed
df2 = df2[df1.columns]  # Makes sure columns are in the same order

# STEP 6: Append vertically (one under the other)
combined_df = pd.concat([df1, df2], ignore_index=True)

# STEP 7: Save the combined CSV back to Drive
output_path = '/content/drive/MyDrive/expermintstarcoder/final-ansible_dataset_befor_varification_full.csv'
combined_df.to_csv(output_path, index=False)

print("✅ Files combined successfully!")
print("📊 Preview:")
print(combined_df.head())
# Out:
# ✅ Files combined successfully!
# 📊 Preview:
#                            Added_lines_fixing_commit  \
# 0  command: php occ config:system:set {{ item.nam...
# 1  when: (not _nextcloud_conf.stat.exists) or (_n...
# 2  when: (nc_sudo_installed_result.rc is defined)...
# 3  action: "{{ ansible_pkg_mgr }} name={{ item }}...
# 4  action: "{{ ansible_pkg_mgr }} name={{ item }}...
#
#                      Added_lines_bug_inducing_commit  \
# 0  - name: "[NC] - Set Nextcloud settings in conf...
# 1  check_mode: no\n  when: _nextcloud_configured....
# 2  register: nc_sudo_installed_result\n  when: nc...
# 3  action: "{{ ansible_pkg_mgr }} name={{ item }}...
# 4  ##\n # BROWSER\n #\n \n- name: jenkins-slave |...
#
#   Fixing_Script_Misconfiguration_Label  \
# 0                                    1
# 1                                    1
# 2                                    1
# 3                                    1
# 4                                    1
#
#             Fixing_Script_MisconfigurationFoundbyLLM  \
# 0  php occ config:set foo \, php occ config:set f...
# 1  when: (not _nextcloud_conf.stat.exists) or (_n...
# 2  when: (nc_sudo_installed_result.rc is defined)...
# 3  action: \, action: \\, action: \\\\, action: \...
# 4  action: \, action: \\, action: \\\\, action: \...
#
#            Fixing_Script_CWE Bug_Inducing_Script_Misconfiguration_Label  \
# 0                    CWE-772                                          1
# 1                    CWE-259                                          1
# 2  CWE-248, CWE-249, CWE-257                                          1
# 3                     CWE-20                                          1
# 4                    CWE-276                                          1
#
#       Bug_Inducing_Script_MisconfigurationFoundbyLLM  \
# 0  command: php occ config:system:set \, mode: 07...
# 1  check_mode: no\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\...
# 2  become: yes\\\\\\\\nbecome_method: sudo\\\\\\\...
# 3                                            action:
# 4      - chromedriver # see selenium role\\n  - c...
#
#                              Bug_Inducing_Script_CWE
# 0  CWE-276, CWE-277, CWE-278, CWE-279, CWE-280, C...
# 1                                 CWE-1111, CWE-1234
# 2        CWE-248, CWE-250, CWE-269, CWE-319, CWE-521
# 3                                           CWE-2000
# 4                                            CWE-949

# %%
import pandas as pd
from sklearn.metrics import precision_recall_fscore_support, accuracy_score

# Load your dataset
df = pd.read_csv('/content/drive/My Drive/expermintstarcoder/ansible_final/final_llama_ansible_dataset.csv')

# Convert truth labels to numeric and drop NaNs
df['verification_Bug_Inducing'] = pd.to_numeric(df['verification_Bug_Inducing'], errors='coerce')
df['verification_Fixing_Script'] = pd.to_numeric(df['verification_Fixing_Script'], errors='coerce')
df.dropna(subset=['verification_Bug_Inducing', 'verification_Fixing_Script'], inplace=True)

# ---------------- Bug-Inducing ----------------
true_bug = df['verification_Bug_Inducing']
predicted_bug = [1] * len(true_bug)  # Always predict 1

bug_accuracy = accuracy_score(true_bug, predicted_bug)
bug_precision, bug_recall, bug_f1, _ = precision_recall_fscore_support(
    true_bug, predicted_bug, average='binary', zero_division=0, pos_label=1
)

# ---------------- Fixing Script ----------------
true_fixing = df['verification_Fixing_Script']
predicted_fixing = [1] * len(true_fixing)  # Always predict 1

fixing_accuracy = accuracy_score(true_fixing, predicted_fixing)
fixing_precision, fixing_recall, fixing_f1, _ = precision_recall_fscore_support(
    true_fixing, predicted_fixing, average='binary', zero_division=0, pos_label=1
)

# ---------------- Overall ----------------
overall_accuracy = (bug_accuracy + fixing_accuracy) / 2
overall_precision = (bug_precision + fixing_precision) / 2
overall_recall = (bug_recall + fixing_recall) / 2
overall_f1 = (bug_f1 + fixing_f1) / 2

# ---------------- Results ----------------
print("----- Bug-Inducing (Always 1 Prediction) -----")
print(f"Precision: {bug_precision:.4f}")
print(f"Recall:    {bug_recall:.4f}")
print(f"F1-score:  {bug_f1:.4f}")
print(f"Accuracy:  {bug_accuracy:.4f}")

print("\n----- Fixing Script (Always 1 Prediction) -----")
print(f"Precision: {fixing_precision:.4f}")
print(f"Recall:    {fixing_recall:.4f}")
print(f"F1-score:  {fixing_f1:.4f}")
print(f"Accuracy:  {fixing_accuracy:.4f}")

print("\n----- Overall Metrics -----")
print(f"Overall Precision: {overall_precision:.4f}")
print(f"Overall Recall:    {overall_recall:.4f}")
print(f"Overall F1-Score:  {overall_f1:.4f}")
print(f"Overall Accuracy:  {overall_accuracy:.4f}")
# Out:
# ----- Bug-Inducing (Always 1 Prediction) -----
# Precision: 0.4022
# Recall:    1.0000
# F1-score:  0.5736
# Accuracy:  0.4022
#
# ----- Fixing Script (Always 1 Prediction) -----
# Precision: 0.5652
# Recall:    1.0000
# F1-score:  0.7222
# Accuracy:  0.5652
#
# ----- Overall Metrics -----
# Overall Precision: 0.4837
# Overall Recall:    1.0000
# Overall F1-Score:  0.6479
# Overall Accuracy:  0.4837
